# %% [markdown]
# # CRS Data Loader v2
#
# Simple 6-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
# 5. **Localizations** (Optional) - Bulk load translations for new languages
# 6. **Workflow** - Complaint state machine (APPLY → ASSIGN → RESOLVE)
#
# ---

# %%
import warnings
import pandas as pd
import requests
from openpyxl import load_workbook
from dataloader.crs_loader import CRSLoader

# %%
# Configuration - Edit these values
URL = "http://kong:8000"
USERNAME = "ADMIN"
PASSWORD = "eGov@123"
TENANT_ID = "pg"  # Root tenant for login
TARGET_TENANT = "kl.citya"  # Target tenant for data (can be child like "pg.citya")

loader = CRSLoader(URL)
loader.login(username=USERNAME, password=PASSWORD, tenant_id=TENANT_ID)

# Create target tenant if it doesn't exist (also enables PGR & HRMS modules)
loader.create_tenant(TARGET_TENANT, "test", users=[
        {"username": "ADMIN", "password": "eGov@123", "name": "Admin",
         "roles": ["SUPERUSER", "EMPLOYEE", "CSR", "GRO", "DGRO", "PGR_LME", "PGR_VIEWER", "CITIZEN"]}
])

loader.login(username="ADMIN", password="eGov@123", tenant_id=TARGET_TENANT)
# Out:
# ✅ Authentication successful!
#    User: ADMIN
#    Name: System Administrator
#    Tenant: pg
#    Token: d7ee123d-14e5-427e-9...
# ✅ Tenant 'kl.citya' already exists
#    ✅ StateInfo already present for 'kl.citya'
# ✅ Authentication successful!
#    User: ADMIN
#    Name: Admin
#    Tenant: kl.citya
#    Token: b6cbb990-cb46-49c9-9...
# True

# %%
# Phase 2a - Generate Boundary Template
# Creates hierarchy definition and downloads an Excel template to fill

BOUNDARY_HIERARCHY = "ADMIN"  # or "ADMIN" 
BOUNDARY_LEVELS = ["State", "District", "Locality"]  # Top to bottom

template_path = loader.load_hierarchy(
    name=BOUNDARY_HIERARCHY,
    levels=BOUNDARY_LEVELS,
    target_tenant=TARGET_TENANT,
    output_dir="upload"
)
print(f"Template saved to: {template_path}")
# Fill the template with your boundary data, then run Phase 2b below
# Out:
# ============================================================
# PHASE 2a: BOUNDARY HIERARCHY & TEMPLATE
# ============================================================
# Tenant: kl.citya
# Hierarchy: ADMIN
# Levels: State -> District -> Locality
#
# [1/4] Building hierarchy definition...
#    Created 3 level definitions
#
# [2/4] Creating hierarchy...
#
# ⚠️  [EXISTS] Boundary hierarchy already exists
#    Tenant: kl.citya
#    Hierarchy Type: ADMIN
#    Hierarchy already exists (OK)
#
# [3/4] Generating template...
#
# ✅ Template generation initiated
#    Task ID: 149838ec-37a5-42f5-8010-85d9fc9dbec0
#    Status: inprogress
#
# [4/4] Waiting for template...
#
# ⏳ Polling for template generation (max 30 attempts)...
#    Attempt 1/30: Status = inprogress
#    Attempt 2/30: Status = completed
#
# ✅ Template generation complete!
#    FileStore ID: 55c2d563-c5f5-4f95-b242-eba805e63af1
#
# 📥 Downloading template...
#    Trying: http://minio:9000/egov-rainmaker/kl.citya/HCM-ADMIN-CONSOLE-SERVER/May/29/1780045481041qlBQKIgRoC.xlsx?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=minioadmin%2F20260529%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20260529T090441Z&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=92f2e5dc59fdd1e83eb15767094a758ca4602ce4463138b9ed96f6e96f0e8e3c
# ✅ Template downloaded: upload/Boundary_Template_kl.citya_ADMIN.xlsx
# 📊 File size: 77795 bytes
#
# ────────────────────────────────────────
# Template downloaded: upload/Boundary_Template_kl.citya_ADMIN.xlsx
# ────────────────────────────────────────
#
# Next steps:
# 1. Open upload/Boundary_Template_kl.citya_ADMIN.xlsx
# 2. Fill in boundary data (codes and names)
# 3. Use loader.load_boundaries() to upload
# Template saved to: upload/Boundary_Template_kl.citya_ADMIN.xlsx

# %%
# Phase 2b - Load Boundaries from filled template
# Use the template path from Phase 2a, or specify your own filled boundary file

BOUNDARY_FILE = "upload/Boundary_Template_kl.citya_ADMIN (2).xlsx"  # Or: "upload/boundary_filled_statea_REVENUE.xlsx"

loader.load_boundaries(BOUNDARY_FILE, target_tenant=TARGET_TENANT, hierarchy_type=BOUNDARY_HIERARCHY)
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary_Template_kl.citya_ADMIN (2).xlsx
# Hierarchy: ADMIN
#
# [1/2] Uploading boundary file...
#
# 📤 Uploading file: Boundary_Template_kl.citya_ADMIN (2).xlsx
# ✅ File uploaded successfully!
#    FileStore ID: a7ccfda9-73ea-41fd-a468-b0ff5ca207e0
#    FileStore ID: a7ccfda9-73ea-41fd-a468-b0ff5ca207e0
#
# [2/2] Processing boundary data...
#
# 📖 Reading boundary data from: upload/Boundary_Template_kl.citya_ADMIN (2).xlsx
#    Found 3 boundary records
#    Columns: ['ADMIN_STATE', 'ADMIN_DISTRICT', 'ADMIN_LOCALITY', 'CRS_BOUNDARY_CODE', 'CRS_LAT', 'CRS_LONG']
#    Hierarchy: State → District → Locality
#    Using row-per-boundary template (code column: CRS_BOUNDARY_CODE)
#    ✅ Created boundary: KL_STATE_MLP
#    ✅ Created relationship: KL_STATE_MLP [State] (root)
#    ✅ Created boundary: KL_DIST_MLP
#    ✅ Created relationship: KL_DIST_MLP [District] (parent: KL_STATE_MLP)
#    ✅ Created boundary: KL_LOC_TIR
#    ✅ Created relationship: KL_LOC_TIR [Locality] (parent: KL_DIST_MLP)
#
# ✅ Boundary processing completed!
#    Boundaries created: 3
#    Relationships created: 3
#
#    Status: completed
# {'status': 'completed',
#  'boundaries_created': 3,
#  'relationships_created': 3,
#  'errors': []}

# %%
# Phase 3 - Common Masters
loader.load_common_masters("dataloader/templates/Common and Complaint Master.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master.xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: kl.citya
#    ✅ Found 2 department(s)
# 📥 Fetching designations from MDMS for tenant: kl.citya
#    ✅ Found 2 designation(s)
# 📥 Fetching departments from MDMS for tenant: kl
#    ✅ Found 13 department(s)
# 📥 Fetching designations from MDMS for tenant: kl
#    ✅ Found 29 designation(s)
#    Existing data on kl.citya: 2 dept(s), 2 desig(s)
#    Existing data on kl: 13 dept(s), 29 desig(s)
#    Departments: 2 existing (reused), 0 new (to create)
#    Designations: 2 existing (reused), 0 new (to create)
# 📥 Fetching designations from MDMS for tenant: kl.citya
#    ✅ Found 2 designation(s)
# 📥 Fetching departments from MDMS for tenant: kl.citya
#    ✅ Found 2 department(s)
#    After load: 2 dept(s), 2 desig(s) on kl.citya
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: kl.citya
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [EXISTS] [1/1] TabBroken (pre-check)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: dataloader/templates/Common and Complaint Master.xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: kl.citya
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created: 0
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'departments': None,
#  'designations': None,
#  'complaint_types': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []}}

# %%
# Phase 4 - Employees
loader.load_employees("dataloader/templates/Employee_Master_Dynamic_statea.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea.xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: kl.citya
#    ✅ Found 2 department(s)
# 📥 Fetching designations from MDMS for tenant: kl.citya
#    ✅ Found 2 designation(s)
# 📥 Fetching roles from MDMS for tenant: kl.citya
#    ✅ Found 22 role(s) from MDMS
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: kl.citya
#    ✅ Found 22 existing roles in MDMS
#    ✅ All 20 required roles already exist in MDMS
#
# ============================================================
# [UPLOADING] HRMS Employees
#    Tenant: kl.citya
#    Records: 1
#    API URL: http://kong:8000/egov-hrms/employees/_create
# ============================================================
#    [EXISTS] [1/1] HARIPRASAD (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Password Updated: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: dataloader/templates/Employee_Master_Dynamic_statea.xlsx
#    Sheet: Employee Master
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# ────────────────────────────────────────
# Employees Summary:
#    Created: 0
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'created': 0, 'exists': 1, 'failed': 0, 'errors': [], 'password_updated': 0}

# %% [markdown]
# ---
#
# ## Phase 5: Localizations (Optional)
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations (Optional)
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
loader.load_localizations("dataloader/templates/localization.xlsx", target_tenant=TARGET_TENANT)

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     "templates/localization.xlsx",
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )
# Out:
# ============================================================
# PHASE 5: LOCALIZATIONS
# ============================================================
# File: localization.xlsx
#    ℹ️  Uploading to STATE tenant 'kl' (not 'kl.citya') — the UI queries localizations at the state level.
#
# [1/2] Reading localization data...
#    Found 5463 messages
#    - en_IN: 5463 messages
#
# [2/2] Uploading localization messages...
#
# [UPLOADING] Localization Messages
#    Tenant: kl
#    Total Messages: 5463
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 5463 messages in batches of 500...
#       ⚠️ Batch 1/11: 500 messages already exist
#       ⚠️ Batch 2/11: 500 messages already exist
#       ⚠️ Batch 3/11: 500 messages already exist
#       ⚠️ Batch 4/11: 500 messages already exist
#       ⚠️ Batch 5/11: 500 messages already exist
#       ⚠️ Batch 6/11: 500 messages already exist
#       ⚠️ Batch 7/11: 500 messages already exist
#       ⚠️ Batch 8/11: 500 messages already exist
#       ⚠️ Batch 9/11: 500 messages already exist
#       ⚠️ Batch 10/11: 500 messages already exist
#       ⚠️ Batch 11/11: 463 messages already exist
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 5463
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Localizations Summary:
#    Created: 0
#    Already existed: 5463
#    Failed: 0
# ────────────────────────────────────────
# {'messages': {'created': 0,
#   'exists': 5463,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []},
#  'stateinfo': None}

# %% [markdown]
# ---
#
# ## Phase 6: Workflow Configuration
#
# Configure the PGR complaint workflow state machine from a JSON file. This defines the complaint lifecycle:
# - **APPLY** → Citizen/CSR creates complaint
# - **PENDINGFORASSIGNMENT** → GRO assigns to field worker
# - **PENDINGATLME** → Field worker resolves or reassigns
# - **RESOLVED/REJECTED** → Terminal states with rating option
#
# **Template:** Use `../default-data-handler/src/main/resources/PgrWorkflowConfig.json` as a starting point.
#
# The JSON file should have a `BusinessServices` array. Use `{tenantid}` as a placeholder - it will be replaced with your target tenant.

# %%
# Phase 6 - Workflow
# Loads the PGR complaint workflow state machine from JSON file

# Default PGR workflow template (copy and modify as needed)
WORKFLOW_JSON = "dataloader/templates/PgrWorkflowConfig.json"

loader.load_workflow(WORKFLOW_JSON, target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 6: WORKFLOW
# ============================================================
# File: PgrWorkflowConfig.json
# Tenant: kl.citya
# Business Service: PGR
#
# [1/3] Loading workflow config from JSON...
#    Loaded 11 states
#
# [2/3] Checking for existing workflow...
#    Found existing workflow: PGR
#    States: 11
#
# [3/3] Workflow already configured (same state count)
# {'status': 'exists', 'error': None, 'states': 11}

# %% [markdown]
# ---
#
# ## Rollback / Delete Data
#
# Use these cells to undo data loading. Run only what you need to rollback.

# %%
# Rollback Phase 2 - Delete Boundaries
# Deletes all boundary entities and relationships for the tenant
loader.delete_boundaries(TARGET_TENANT)
# Out:
# ============================================================
# DELETING BOUNDARIES
# ============================================================
# Tenant: kl.citya
#
# 🗑️ Deleting all boundaries for tenant: kl.citya
#    Found 50 boundaries to delete
#    ❌ Failed to delete TEST_BND_AUTH: 400
#    ❌ Failed to delete BOMET_BOMET_EAST_KEMBU: 400
#    ❌ Failed to delete BOMET_KONOIN_BOITO: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL: 400
#    ❌ Failed to delete BOMET_BOMET_EAST_LONGISA: 400
#    ❌ Failed to delete BOMET_KONOIN_MOGOGOSIEK: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL_SILIBWET_TOWNSHIP: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL_NADARAWETA: 400
#    ❌ Failed to delete BOMET_KONOIN_CHEPCHABAS: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL_SINGORWET: 400
#    ❌ Failed to delete BOMET_KONOIN_EMBOMOS: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL_MUTARAKWA: 400
#    ❌ Failed to delete BOMET_BOMET_EAST_MERIGI: 400
#    ❌ Failed to delete BOMET_BOMET_CENTRAL_CHESOEN: 400
#    ❌ Failed to delete BOMET_KONOIN_KIMULOT: 400
#    ❌ Failed to delete BOMET_BOMET_EAST_KIPRERES: 400
#    ❌ Failed to delete BOMET_KONOIN: 400
#    ❌ Failed to delete BOMET_BOMET_EAST_CHEMANER: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU_KONG_ASIS: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU_NYANGORES: 400
#    ❌ Failed to delete BOMET_SOTIK_CHEMAGEL: 400
#    ❌ Failed to delete BOMET_SOTIK_NDANAI_ABOSI: 400
#    ❌ Failed to delete BOMET_BOMET_EAST: 400
#    ❌ Failed to delete BOMET_SOTIK_RONGENA_MANARET: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU_SIGOR: 400
#    ❌ Failed to delete BOMET_SOTIK_KIPSONOI: 400
#    ❌ Failed to delete BOMET_SOTIK_APLETUNDO: 400
#    ❌ Failed to delete BOMET_SOTIK: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU_CHEBUNYO: 400
#    ❌ Failed to delete BOMET: 400
#    ❌ Failed to delete BOMET_CHEPALUNGU_SIONGIROI: 400
#    ❌ Failed to delete SUN03_ADMIN_LOCALITY: 400
#    ❌ Failed to delete SUN01_ADMIN_LOCALITY: 400
#    ❌ Failed to delete B1_ADMIN_BLOCK: 400
#    ❌ Failed to delete Z1_ADMIN_ZONE: 400
#    ❌ Failed to delete City: 400
#    ❌ Failed to delete SUN02_ADMIN_LOCALITY: 400
#    ❌ Failed to delete PG_CITYA_ADMIN_CITY: 400
#    ❌ Failed to delete PB_PTK_DNN: 400
#    ❌ Failed to delete PB_PTK_PTK: 400
#    ❌ Failed to delete PB_PTK: 400
#    ❌ Failed to delete PB_FRD_JTN: 400
#    ❌ Failed to delete PB_FRD_KTK: 400
#    ❌ Failed to delete PB_FRD_FRD: 400
#    ❌ Failed to delete PB_FRD: 400
#    ❌ Failed to delete PB_MKT_GDW: 400
#    ❌ Failed to delete PB_MKT_MLT: 400
#    ❌ Failed to delete PB_MKT_MKT: 400
#    ❌ Failed to delete PB_MKT: 400
#
#    Summary: Deleted 0, Failed 50
#    Boundary API didn't delete, trying DB method...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Rollback Phase 2 - Delete Boundaries
#       2 # Deletes all boundary entities and relationships for the tenant
# ----> 3 loader.delete_boundaries(TARGET_TENANT)
#
# File /home/jovyan/work/dataloader/crs_loader.py:1854, in delete_boundaries(self, target_tenant, use_db)
#    1853 def delete_boundaries(self, target_tenant: str = None, use_db: bool = False) -> Dict:
# -> 1854     """Delete all boundary entities for a tenant
#    1855
#    1856     Args:
#    1857         target_tenant: Tenant ID (e.g., 'statea', 'pg.citya')
#    1858         use_db: If True, use direct DB access (requires kubectl). Default: False (use API)
#    1859
#    1860     Returns:
#    1861         dict: {deleted: int, relationships_deleted: int, status: str}
#    1862     """
#    1863     self._check_auth()
#    1864     tenant = target_tenant or self.tenant_id
#
# File /home/jovyan/work/dataloader/crs_loader.py:1884, in _delete_boundaries_via_api(self, tenant)
#    1876 def _delete_boundaries_via_api(self, tenant: str) -> Dict:
#    1877     """Delete boundaries using the boundary service API
#    1878
#    1879     Fallback chain:
#    (...)   1882     3. kubectl API server (for CI environments)
#    1883     """
# -> 1884     # Try boundary service API first
#    1885     result = self.uploader.delete_all_boundaries(tenant)
#    1887     deleted = result.get('deleted', 0)
#
# File /home/jovyan/work/dataloader/crs_loader.py:1905, in _delete_boundaries_via_db(self, tenant)
#    1903 print("   Boundary API didn't delete, trying DB method...")
#    1904 db_result = self._delete_boundaries_via_db(tenant)
# -> 1905 if db_result.get('status') == 'success':
#    1906     return db_result
#    1908 # Try kubectl API server (for CI without kubectl)
#
# File /usr/local/lib/python3.12/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /usr/local/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/local/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kubectl'

# %%
# Rollback Phase 3 - Delete Common Masters
# Deletes departments, designations, and complaint types
loader.rollback_common_masters(TARGET_TENANT)

# %%
# Rollback Phase 1 - Delete Tenant Config
# Deletes tenant and branding configuration
loader.rollback_tenant(TARGET_TENANT)

# %%
# Delete specific MDMS schema data (granular control)
loader.delete_mdms("common-masters.Department", TARGET_TENANT)
loader.delete_mdms("common-masters.Designation", TARGET_TENANT)
loader.delete_mdms("RAINMAKER-PGR.ServiceDefs", TARGET_TENANT)

# %%
# FULL RESET - Delete everything (MDMS + Boundaries)
# WARNING: This deletes ALL data for the tenant!
loader.full_reset("REVENUE", TARGET_TENANT)

# %% [markdown]
# **Note:** Employees (Phase 4) cannot be deleted via API - they are managed in HRMS and must be deactivated manually if needed.
