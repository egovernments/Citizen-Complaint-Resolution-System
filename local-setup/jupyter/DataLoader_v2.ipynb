# %% [markdown]
# # CRS Data Loader v2
#
# Simple 6-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
# 5. **Localizations** (Optional) - Bulk load translations for new languages
# 6. **Workflow** - Complaint state machine (APPLY → ASSIGN → RESOLVE)
#
# ---

# %%
import warnings
import pandas as pd
import requests
from openpyxl import load_workbook
from dataloader.crs_loader import CRSLoader

# %%
# Configuration - Edit these values
URL = "http://kong:8000"
USERNAME = "ADMIN"
PASSWORD = "eGov@123"
TENANT_ID = "pg"  # Root tenant for login
TARGET_TENANT = "statea.f"  # Target tenant for data (can be child like "pg.citya")

loader = CRSLoader(URL)
loader.login(username=USERNAME, password=PASSWORD, tenant_id=TENANT_ID)

# Create target tenant if it doesn't exist (also enables PGR & HRMS modules)
loader.create_tenant(TARGET_TENANT, "My Tenant", users=[
      {"username": "ADMIN", "password": "eGov@123", "name": "Admin",
       "roles": ["SUPERUSER", "EMPLOYEE"]}
  ])

loader.login(username="ADMIN", password="eGov@123", tenant_id="statea.f")
# Out:
# ✅ Authentication successful!
#    User: ADMIN
#    Name: System Administrator
#    Tenant: pg
#    Token: ee1d38e7-eaaa-4a2f-9...
# ✅ Tenant 'statea.f' already exists
# ✅ Authentication successful!
#    User: ADMIN
#    Name: Admin
#    Tenant: statea.f
#    Token: 0f87263c-be58-4022-8...
# True

# %%
# Phase 2a - Generate Boundary Template
# Creates hierarchy definition and downloads an Excel template to fill

BOUNDARY_HIERARCHY = "R"  # or "ADMIN" 
BOUNDARY_LEVELS = ["State", "District", "Tehsil"]  # Top to bottom

template_path = loader.load_hierarchy(
    name=BOUNDARY_HIERARCHY,
    levels=BOUNDARY_LEVELS,
    target_tenant=TARGET_TENANT,
    output_dir="upload"
)
print(f"Template saved to: {template_path}")
# Fill the template with your boundary data, then run Phase 2b below
# Out:
# ============================================================
# PHASE 2a: BOUNDARY HIERARCHY & TEMPLATE
# ============================================================
# Tenant: statea.f
# Hierarchy: R
# Levels: State -> District -> Tehsil
#
# [1/4] Building hierarchy definition...
#    Created 3 level definitions
#
# [2/4] Creating hierarchy...
#
# ✅ [SUCCESS] Boundary hierarchy created
#    Tenant: statea.f
#    Hierarchy Type: R
#    Levels: 3
#    Hierarchy created successfully
#
# [3/4] Generating template...
#
# ✅ Template generation initiated
#    Task ID: 3b0d1503-4502-4d08-97dd-513293cbebf7
#    Status: inprogress
#
# [4/4] Waiting for template...
#
# ⏳ Polling for template generation (max 30 attempts)...
#    Attempt 1/30: Status = inprogress
#    Attempt 2/30: Status = inprogress
#    Attempt 3/30: Status = completed
#
# ✅ Template generation complete!
#    FileStore ID: 77d432a3-1c41-4c54-80c4-7e5ad0579241
#
# 📥 Downloading from S3...
# ✅ Template downloaded: upload/Boundary_Template_statea.f_R.xlsx
# 📊 File size: 77788 bytes
#
# ────────────────────────────────────────
# Template downloaded: upload/Boundary_Template_statea.f_R.xlsx
# ────────────────────────────────────────
#
# Next steps:
# 1. Open upload/Boundary_Template_statea.f_R.xlsx
# 2. Fill in boundary data (codes and names)
# 3. Use loader.load_boundaries() to upload
# Template saved to: upload/Boundary_Template_statea.f_R.xlsx

# %%
# Phase 2b - Load Boundaries from filled template
# Use the template path from Phase 2a, or specify your own filled boundary file

BOUNDARY_FILE = "templates/Boundary_Master.xlsx"  # Or: "upload/boundary_filled_statea_REVENUE.xlsx"

loader.load_boundaries(BOUNDARY_FILE, target_tenant=TARGET_TENANT, hierarchy_type=BOUNDARY_HIERARCHY)
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary_Master.xlsx
# Hierarchy: R
#
# [1/2] Uploading boundary file...
#
# 📤 Uploading file: Boundary_Master.xlsx
# ✅ File uploaded successfully!
#    FileStore ID: 9b056613-5281-4b73-a989-ff324265f4ac
#    FileStore ID: 9b056613-5281-4b73-a989-ff324265f4ac
#
# [2/2] Processing boundary data...
#
# 📖 Reading boundary data from: templates/Boundary_Master.xlsx
#    Found 88 boundary records
#    Columns: ['code', 'name', 'boundaryType', 'parentCode']
#    Hierarchy: State → District → Tehsil
#    Using standard format (code, boundaryType, parentCode)
#    Boundary types match hierarchy - no mapping needed
#    ✅ Created boundary: PB
#    ✅ Created relationship: PB [State] (root)
#    ✅ Created boundary: PB_AMR
#    ✅ Created relationship: PB_AMR [District] (parent: PB)
#    ✅ Created boundary: PB_AMR_AJN
#    ✅ Created relationship: PB_AMR_AJN [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_BBK
#    ✅ Created relationship: PB_AMR_BBK [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_AM1
#    ✅ Created relationship: PB_AMR_AM1 [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_AM2
#    ✅ Created relationship: PB_AMR_AM2 [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_LDH
#    ✅ Created relationship: PB_LDH [District] (parent: PB)
#    ✅ Created boundary: PB_LDH_LDH
#    ✅ Created relationship: PB_LDH_LDH [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_KHN
#    ✅ Created relationship: PB_LDH_KHN [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_SAM
#    ✅ Created relationship: PB_LDH_SAM [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_JAG
#    ✅ Created relationship: PB_LDH_JAG [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_JAL
#    ✅ Created relationship: PB_JAL [District] (parent: PB)
#    ✅ Created boundary: PB_JAL_JAL
#    ✅ Created relationship: PB_JAL_JAL [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_JAL_NAK
#    ✅ Created relationship: PB_JAL_NAK [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_JAL_PHG
#    ✅ Created relationship: PB_JAL_PHG [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_PTL
#    ✅ Created relationship: PB_PTL [District] (parent: PB)
#    ✅ Created boundary: PB_PTL_PTL
#    ✅ Created relationship: PB_PTL_PTL [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_PTL_RAJ
#    ✅ Created relationship: PB_PTL_RAJ [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_PTL_NAB
#    ❌ Failed relationship PB_PTL_NAB: Boundary entity does not exist.
#    ✅ Created boundary: PB_PTL_SAM
#    ✅ Created relationship: PB_PTL_SAM [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_BTH
#    ✅ Created relationship: PB_BTH [District] (parent: PB)
#    ✅ Created boundary: PB_BTH_BTH
#    ✅ Created relationship: PB_BTH_BTH [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_BTH_TAL
#    ✅ Created relationship: PB_BTH_TAL [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_BTH_RAM
#    ✅ Created relationship: PB_BTH_RAM [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_FZK
#    ✅ Created relationship: PB_FZK [District] (parent: PB)
#    ✅ Created boundary: PB_FZK_FZK
#    ✅ Created relationship: PB_FZK_FZK [Tehsil] (parent: PB_FZK)
#    ✅ Created boundary: PB_FZK_ABO
#    ✅ Created relationship: PB_FZK_ABO [Tehsil] (parent: PB_FZK)
#    ✅ Created boundary: PB_SNG
#    ❌ Failed relationship PB_SNG: Boundary entity does not exist.
#    ✅ Created boundary: PB_SNG_SNG
#    ❌ Failed relationship PB_SNG_SNG: Boundary entity does not exist.
#    ✅ Created boundary: PB_SNG_AHM
#    ❌ Failed relationship PB_SNG_AHM: Boundary entity does not exist.
#    ✅ Created boundary: PB_SNG_BHW
#    ❌ Failed relationship PB_SNG_BHW: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_SNG_MLK
#    ❌ Failed relationship PB_SNG_MLK: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_HSP
#    ❌ Failed relationship PB_HSP: Boundary entity does not exist.
#    ✅ Created boundary: PB_HSP_HSP
#    ❌ Failed relationship PB_HSP_HSP: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_HSP_DAS
#    ❌ Failed relationship PB_HSP_DAS: Boundary entity does not exist.
#    ✅ Created boundary: PB_HSP_GAR
#    ❌ Failed relationship PB_HSP_GAR: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_GDS
#    ✅ Created relationship: PB_GDS [District] (parent: PB)
#    ✅ Created boundary: PB_GDS_GDS
#    ✅ Created relationship: PB_GDS_GDS [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_GDS_BTL
#    ✅ Created relationship: PB_GDS_BTL [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_GDS_DBN
#    ✅ Created relationship: PB_GDS_DBN [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_KPT
#    ✅ Created relationship: PB_KPT [District] (parent: PB)
#    ✅ Created boundary: PB_KPT_KPT
#    ✅ Created relationship: PB_KPT_KPT [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_KPT_BHL
#    ✅ Created relationship: PB_KPT_BHL [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_KPT_PHG
#    ✅ Created relationship: PB_KPT_PHG [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_MOG
#    ✅ Created relationship: PB_MOG [District] (parent: PB)
#    ✅ Created boundary: PB_MOG_MOG
#    ✅ Created relationship: PB_MOG_MOG [Tehsil] (parent: PB_MOG)
#    ✅ Created boundary: PB_MOG_BAG
#    ✅ Created relationship: PB_MOG_BAG [Tehsil] (parent: PB_MOG)
#    ✅ Created boundary: PB_FGS
#    ✅ Created relationship: PB_FGS [District] (parent: PB)
#    ✅ Created boundary: PB_FGS_FGS
#    ✅ Created relationship: PB_FGS_FGS [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_FGS_AML
#    ✅ Created relationship: PB_FGS_AML [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_FGS_BSP
#    ✅ Created relationship: PB_FGS_BSP [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_RPN
#    ✅ Created relationship: PB_RPN [District] (parent: PB)
#    ✅ Created boundary: PB_RPN_RPN
#    ✅ Created relationship: PB_RPN_RPN [Tehsil] (parent: PB_RPN)
#    ✅ Created boundary: PB_RPN_ANS
#    ❌ Failed relationship PB_RPN_ANS: Boundary entity does not exist.
#    ✅ Created boundary: PB_SAS
#    ✅ Created relationship: PB_SAS [District] (parent: PB)
#    ✅ Created boundary: PB_SAS_MOH
#    ❌ Failed relationship PB_SAS_MOH: Boundary entity does not exist.
#    ✅ Created boundary: PB_SAS_DBS
#    ✅ Created relationship: PB_SAS_DBS [Tehsil] (parent: PB_SAS)
#    ✅ Created boundary: PB_SAS_KHR
#    ❌ Failed relationship PB_SAS_KHR: Boundary entity does not exist.
#    ✅ Created boundary: PB_SBS
#    ❌ Failed relationship PB_SBS: Boundary entity does not exist.
#    ✅ Created boundary: PB_SBS_NWS
#    ❌ Failed relationship PB_SBS_NWS: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_SBS_BLC
#    ❌ Failed relationship PB_SBS_BLC: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_SBS_BNG
#    ❌ Failed relationship PB_SBS_BNG: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_TRN
#    ❌ Failed relationship PB_TRN: Boundary entity does not exist.
#    ✅ Created boundary: PB_TRN_TRN
#    ❌ Failed relationship PB_TRN_TRN: Boundary entity does not exist.
#    ✅ Created boundary: PB_TRN_BHK
#    ❌ Failed relationship PB_TRN_BHK: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_TRN_PTT
#    ❌ Failed relationship PB_TRN_PTT: Parent entity for current boundary relationship does not exist.
#    ✅ Created boundary: PB_BRN
#    ✅ Created relationship: PB_BRN [District] (parent: PB)
#    ✅ Created boundary: PB_BRN_BRN
#    ✅ Created relationship: PB_BRN_BRN [Tehsil] (parent: PB_BRN)
#    ✅ Created boundary: PB_BRN_TPA
#    ✅ Created relationship: PB_BRN_TPA [Tehsil] (parent: PB_BRN)
#    ✅ Created boundary: PB_MNS
#    ✅ Created relationship: PB_MNS [District] (parent: PB)
#    ✅ Created boundary: PB_MNS_MNS
#    ✅ Created relationship: PB_MNS_MNS [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_MNS_BDR
#    ✅ Created relationship: PB_MNS_BDR [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_MNS_SRD
#    ✅ Created relationship: PB_MNS_SRD [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_FRP
#    ✅ Created relationship: PB_FRP [District] (parent: PB)
#    ✅ Created boundary: PB_FRP_FRP
#    ✅ Created relationship: PB_FRP_FRP [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_FRP_ZRA
#    ✅ Created relationship: PB_FRP_ZRA [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_FRP_GUR
#    ✅ Created relationship: PB_FRP_GUR [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_MKT
#    ✅ Created relationship: PB_MKT [District] (parent: PB)
#    ✅ Created boundary: PB_MKT_MKT
#    ✅ Created relationship: PB_MKT_MKT [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_MKT_MLT
#    ✅ Created relationship: PB_MKT_MLT [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_MKT_GDW
#    ✅ Created relationship: PB_MKT_GDW [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_FRD
#    ✅ Created relationship: PB_FRD [District] (parent: PB)
#    ✅ Created boundary: PB_FRD_FRD
#    ✅ Created relationship: PB_FRD_FRD [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_FRD_KTK
#    ✅ Created relationship: PB_FRD_KTK [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_FRD_JTN
#    ✅ Created relationship: PB_FRD_JTN [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_PTK
#    ✅ Created relationship: PB_PTK [District] (parent: PB)
#    ✅ Created boundary: PB_PTK_PTK
#    ✅ Created relationship: PB_PTK_PTK [Tehsil] (parent: PB_PTK)
#    ✅ Created boundary: PB_PTK_DNN
#    ✅ Created relationship: PB_PTK_DNN [Tehsil] (parent: PB_PTK)
#
# ✅ Boundary processing completed!
#    Boundaries created: 88
#    Relationships created: 67
#
#    Status: completed
# {'status': 'completed',
#  'boundaries_created': 88,
#  'relationships_created': 67,
#  'errors': []}

# %%
# Phase 3 - Common Masters
loader.load_common_masters("templates/Common and Complaint Master.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master.xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: statea.f
#    ✅ Found 13 department(s)
# 📥 Fetching designations from MDMS for tenant: statea.f
#    ✅ Found 29 designation(s)
#    Creating 2 departments...
#
# [UPLOADING] common-masters.Department
#    Tenant: statea.f
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Department
# ============================================================
#    [OK] [1/2] DEPT_36
#    [OK] [2/2] DEPT_37
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Department
#    ⚠️  Sheet 'Department' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: statea.f
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    Creating 2 designations...
#
# [UPLOADING] common-masters.Designation
#    Tenant: statea.f
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [OK] [1/2] DESIG_1002
#    [OK] [2/2] DESIG_1003
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Designation
#    ⚠️  Sheet 'Designation' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: statea.f
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: statea.f
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [OK] [1/1] TabBroken
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: statea.f
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created: 5
#    Already existed: 0
#    Failed: 0
# ────────────────────────────────────────
# {'departments': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'designations': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'complaint_types': {'created': 1, 'exists': 0, 'failed': 0, 'errors': []}}

# %%
# Phase 4 - Employees
loader.load_employees("templates/Employee_Master_Dynamic_statea.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea.xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: statea.f
#    ✅ Found 2 department(s)
# 📥 Fetching designations from MDMS for tenant: statea.f
#    ✅ Found 2 designation(s)
# 📥 Fetching roles from MDMS for tenant: statea.f
#    ✅ Found 21 role(s) from MDMS
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: statea.f
#    ✅ Found 21 existing roles in MDMS
#    ✅ All 20 required roles already exist in MDMS
#
# ============================================================
# [UPLOADING] HRMS Employees
#    Tenant: statea.f
#    Records: 1
#    API URL: http://kong:8000/egov-hrms/employees/_create
# ============================================================
#    [EXISTS] [1/1] SAMPLE_EMPLOYEE (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Password Updated: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Employee_Master_Dynamic_statea.xlsx
#    Sheet: Employee Master
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# ────────────────────────────────────────
# Employees Summary:
#    Created: 0
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'created': 0, 'exists': 1, 'failed': 0, 'errors': [], 'password_updated': 0}

# %% [markdown]
# ---
#
# ## Phase 5: Localizations (Optional)
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations (Optional)
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
loader.load_localizations("templates/localization.xlsx", target_tenant=TARGET_TENANT)

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     "templates/localization.xlsx",
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )
# Out:
# ============================================================
# PHASE 5: LOCALIZATIONS
# ============================================================
# File: localization.xlsx
#
# [1/2] Reading localization data...
#    Found 45143 messages
#    - en_IN: 45143 messages
#
# [2/2] Uploading localization messages...
#
# [UPLOADING] Localization Messages
#    Tenant: statea.f
#    Total Messages: 45143
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 45143 messages in batches of 500...
#       ⚠️ Batch 1/91: 500 messages already exist
#       ⚠️ Batch 2/91: 500 messages already exist
#       ⚠️ Batch 3/91: 500 messages already exist
#       ⚠️ Batch 4/91: 500 messages already exist
#       ⚠️ Batch 5/91: 500 messages already exist
#       ⚠️ Batch 6/91: 500 messages already exist
#       ⚠️ Batch 7/91: 500 messages already exist
#       ⚠️ Batch 8/91: 500 messages already exist
#       ⚠️ Batch 9/91: 500 messages already exist
#       ⚠️ Batch 10/91: 500 messages already exist
#       ⚠️ Batch 11/91: 500 messages already exist
#       ⚠️ Batch 12/91: 500 messages already exist
#       ⚠️ Batch 13/91: 500 messages already exist
#       ⚠️ Batch 14/91: 500 messages already exist
#       ⚠️ Batch 15/91: 500 messages already exist
#       ⚠️ Batch 16/91: 500 messages already exist
#       ⚠️ Batch 17/91: 500 messages already exist
#       ⚠️ Batch 18/91: 500 messages already exist
#       ⚠️ Batch 19/91: 500 messages already exist
#       ⚠️ Batch 20/91: 500 messages already exist
#       ⚠️ Batch 21/91: 500 messages already exist
#       ⚠️ Batch 22/91: 500 messages already exist
#       ⚠️ Batch 23/91: 500 messages already exist
#       ⚠️ Batch 24/91: 500 messages already exist
#       ✅ Batch 25/91: 500 messages uploaded
#       ✅ Batch 26/91: 500 messages uploaded
#       ⚠️ Batch 27/91: 500 messages already exist
#       ⚠️ Batch 28/91: 500 messages already exist
#       ⚠️ Batch 29/91: 500 messages already exist
#       ⚠️ Batch 30/91: 500 messages already exist
#       ⚠️ Batch 31/91: 500 messages already exist
#       ⚠️ Batch 32/91: 500 messages already exist
#       ✅ Batch 33/91: 500 messages uploaded
#       ⚠️ Batch 34/91: 500 messages already exist
#       ⚠️ Batch 35/91: 500 messages already exist
#       ⚠️ Batch 36/91: 500 messages already exist
#       ⚠️ Batch 37/91: 500 messages already exist
#       ⚠️ Batch 38/91: 500 messages already exist
#       ⚠️ Batch 39/91: 500 messages already exist
#       ✅ Batch 40/91: 500 messages uploaded
#       ✅ Batch 41/91: 500 messages uploaded
#       ⚠️ Batch 42/91: 500 messages already exist
#       ⚠️ Batch 43/91: 500 messages already exist
#       ✅ Batch 44/91: 500 messages uploaded
#       ✅ Batch 45/91: 500 messages uploaded
#       ⚠️ Batch 46/91: 500 messages already exist
#       ⚠️ Batch 47/91: 500 messages already exist
#       ⚠️ Batch 48/91: 500 messages already exist
#       ⚠️ Batch 49/91: 500 messages already exist
#       ⚠️ Batch 50/91: 500 messages already exist
#       ⚠️ Batch 51/91: 500 messages already exist
#       ⚠️ Batch 52/91: 500 messages already exist
#       ⚠️ Batch 53/91: 500 messages already exist
#       ⚠️ Batch 54/91: 500 messages already exist
#       ⚠️ Batch 55/91: 500 messages already exist
#       ⚠️ Batch 56/91: 500 messages already exist
#       ⚠️ Batch 57/91: 500 messages already exist
#       ⚠️ Batch 58/91: 500 messages already exist
#       ⚠️ Batch 59/91: 500 messages already exist
#       ⚠️ Batch 60/91: 500 messages already exist
#       ⚠️ Batch 61/91: 500 messages already exist
#       ⚠️ Batch 62/91: 500 messages already exist
#       ⚠️ Batch 63/91: 500 messages already exist
#       ⚠️ Batch 64/91: 500 messages already exist
#       ⚠️ Batch 65/91: 500 messages already exist
#       ⚠️ Batch 66/91: 500 messages already exist
#       ⚠️ Batch 67/91: 500 messages already exist
#       ⚠️ Batch 68/91: 500 messages already exist
#       ⚠️ Batch 69/91: 500 messages already exist
#       ✅ Batch 70/91: 500 messages uploaded
#       ✅ Batch 71/91: 500 messages uploaded
#       ⚠️ Batch 72/91: 500 messages already exist
#       ⚠️ Batch 73/91: 500 messages already exist
#       ⚠️ Batch 74/91: 500 messages already exist
#       ⚠️ Batch 75/91: 500 messages already exist
#       ⚠️ Batch 76/91: 500 messages already exist
#       ⚠️ Batch 77/91: 500 messages already exist
#       ⚠️ Batch 78/91: 500 messages already exist
#       ⚠️ Batch 79/91: 500 messages already exist
#       ⚠️ Batch 80/91: 500 messages already exist
#       ⚠️ Batch 81/91: 500 messages already exist
#       ⚠️ Batch 82/91: 500 messages already exist
#       ⚠️ Batch 83/91: 500 messages already exist
#       ⚠️ Batch 84/91: 500 messages already exist
#       ⚠️ Batch 85/91: 500 messages already exist
#       ⚠️ Batch 86/91: 500 messages already exist
#       ⚠️ Batch 87/91: 500 messages already exist
#       ⚠️ Batch 88/91: 500 messages already exist
#       ⚠️ Batch 89/91: 500 messages already exist
#       ⚠️ Batch 90/91: 500 messages already exist
#       ⚠️ Batch 91/91: 143 messages already exist
# ============================================================
# [SUMMARY] Created: 4500
# [SUMMARY] Already Exists: 40643
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Localizations Summary:
#    Created: 4500
#    Already existed: 40643
#    Failed: 0
# ────────────────────────────────────────
# {'messages': {'created': 4500,
#   'exists': 40643,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []},
#  'stateinfo': None}

# %% [markdown]
# ---
#
# ## Phase 6: Workflow Configuration
#
# Configure the PGR complaint workflow state machine from a JSON file. This defines the complaint lifecycle:
# - **APPLY** → Citizen/CSR creates complaint
# - **PENDINGFORASSIGNMENT** → GRO assigns to field worker
# - **PENDINGATLME** → Field worker resolves or reassigns
# - **RESOLVED/REJECTED** → Terminal states with rating option
#
# **Template:** Use `../default-data-handler/src/main/resources/PgrWorkflowConfig.json` as a starting point.
#
# The JSON file should have a `BusinessServices` array. Use `{tenantid}` as a placeholder - it will be replaced with your target tenant.

# %%
# Phase 6 - Workflow
# Loads the PGR complaint workflow state machine from JSON file

# Default PGR workflow template (copy and modify as needed)
WORKFLOW_JSON = "templates/PgrWorkflowConfig.json"

loader.load_workflow(WORKFLOW_JSON, target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 6: WORKFLOW
# ============================================================
# File: PgrWorkflowConfig.json
# Tenant: statea.f
# Business Service: PGR
#
# [1/3] Loading workflow config from JSON...
#    Loaded 11 states
#
# [2/3] Checking for existing workflow...
#    Found existing workflow: PGR
#    States: 11
#
# [3/3] Workflow already configured (same state count)
# {'status': 'exists', 'error': None, 'states': 11}

# %% [markdown]
# ---
#
# ## Rollback / Delete Data
#
# Use these cells to undo data loading. Run only what you need to rollback.

# %%
# Rollback Phase 2 - Delete Boundaries
# Deletes all boundary entities and relationships for the tenant
loader.delete_boundaries(TARGET_TENANT)

# %%
# Rollback Phase 3 - Delete Common Masters
# Deletes departments, designations, and complaint types
loader.rollback_common_masters(TARGET_TENANT)

# %%
# Rollback Phase 1 - Delete Tenant Config
# Deletes tenant and branding configuration
loader.rollback_tenant(TARGET_TENANT)

# %%
# Delete specific MDMS schema data (granular control)
loader.delete_mdms("common-masters.Department", TARGET_TENANT)
loader.delete_mdms("common-masters.Designation", TARGET_TENANT)
loader.delete_mdms("RAINMAKER-PGR.ServiceDefs", TARGET_TENANT)

# %%
# FULL RESET - Delete everything (MDMS + Boundaries)
# WARNING: This deletes ALL data for the tenant!
loader.full_reset("REVENUE", TARGET_TENANT)

# %% [markdown]
# **Note:** Employees (Phase 4) cannot be deleted via API - they are managed in HRMS and must be deactivated manually if needed.
