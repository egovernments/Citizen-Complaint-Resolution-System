# %% [markdown]
# # CRS Data Loader v2
#
# Simple 6-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
# 5. **Localizations** (Optional) - Bulk load translations for new languages
# 6. **Workflow** - Complaint state machine (APPLY → ASSIGN → RESOLVE)
#
# ---

# %%
import warnings
import pandas as pd
import requests
from openpyxl import load_workbook
from dataloader.crs_loader import CRSLoader
from pathlib import Path

# %%
# Configuration - Edit these values
URL = "http://kong:8000"
USERNAME = "ADMIN"
PASSWORD = "eGov@123"
TENANT_ID = "pg"  # Root tenant for login
TARGET_TENANT = "old.bat"  # Target tenant for data (can be child like "pg.citya")
ROOT_TENANT = "old"

loader = CRSLoader(URL)
loader.login(username=USERNAME, password=PASSWORD, tenant_id=TENANT_ID)

# Create target tenant if it doesn't exist (also enables PGR & HRMS modules)
loader.create_tenant(TARGET_TENANT, "My Tenant", users=[
      {"username": "ADMIN", "password": "eGov@123", "name": "Admin",
       "roles": ["SUPERUSER", "EMPLOYEE"]}
  ])

loader.login(username=USERNAME, password=PASSWORD, tenant_id=TARGET_TENANT)

# Resolve template directory reliably regardless of notebook launch directory
if (Path.cwd() / "dataloader" / "templates").exists():
    TEMPLATE_DIR = Path.cwd() / "dataloader" / "templates"
elif (Path.cwd() / "templates").exists():
    TEMPLATE_DIR = Path.cwd() / "templates"
else:
    raise FileNotFoundError("Could not locate templates directory. Expected ./templates or ./dataloader/templates")
# Out:
# ✅ Authentication successful!
#    User: ADMIN
#    Name: System Administrator
#    Tenant: pg
#    Token: 8cd0a805-8e1f-43d7-a...
# 📝 Creating tenant 'old.bat'...
# 🔧 New root tenant detected: 'old' (different from session root 'pg')
# 🚀 Bootstrapping new root tenant 'old'...
#
# 🔧 Bootstrapping new tenant root 'old' from 'pg'...
#    📝 Setting STATE_LEVEL_TENANT_ID to 'old' for UI rendering...
#    ✓ Environment variable STATE_LEVEL_TENANT_ID set to 'old'
#    ✅ Stored current root tenant 'old' in nginx/current-tenant.json
#    💡 GlobalConfigs.js can now read this file to get the active tenant
#    📋 Schemas: 30 copied, 1 already existed, 0 failed (of 31 total)
#    ⏳ Waiting 10 seconds for schema propagation...
#    ✅ Created essential schema: boundary-v2.BoundaryType
#    ✅ Created essential schema: boundary-v2.HierarchyType
#    ✅ Created essential schema: project-factory.CampaignType
#    ⏳ Waiting 5 more seconds after essential schema creation...
#
# [UPLOADING] boundary-v2.HierarchyType
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/boundary-v2.HierarchyType
# ============================================================
#    [OK] [1/1] ADMIN
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ Created 1 boundary-v2.HierarchyType records
#
# [UPLOADING] boundary-v2.BoundaryType
#    Tenant: old
#    Records: 3
#    API URL: http://kong:8000/mdms-v2/v2/_create/boundary-v2.BoundaryType
# ============================================================
#    [OK] [1/3] State
#    [OK] [2/3] District
#    [OK] [3/3] Locality
# ============================================================
# [SUMMARY] Created: 3
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ Created 3 boundary-v2.BoundaryType records
#
# [UPLOADING] project-factory.CampaignType
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/project-factory.CampaignType
# ============================================================
#    [OK] [1/1] BOUNDARY_SETUP
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ Created 1 project-factory.CampaignType records
#
# [UPLOADING] tenant.tenants
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/tenant.tenants
# ============================================================
#    [OK] [1/1] old
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ Root tenant record created for 'old'
#
# [UPLOADING] common-masters.IdFormat
#    Tenant: old
#    Records: 178
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.IdFormat
# ============================================================
#    [OK] [1/178] 1
#    [OK] [2/178] 2
#    [OK] [3/178] 3
#    [OK] [4/178] 4
#    [OK] [5/178] 5
#    [OK] [6/178] 6
#    [OK] [7/178] 7
#    [OK] [8/178] 8
#    [OK] [9/178] 9
#    [OK] [10/178] 10
#    [OK] [11/178] 11
#    [OK] [12/178] 12
#    [OK] [13/178] 13
#    [OK] [14/178] 14
#    [OK] [15/178] 15
#    [OK] [16/178] 16
#    [OK] [17/178] 17
#    [OK] [18/178] 18
#    [OK] [19/178] 19
#    [OK] [20/178] 20
#    [OK] [21/178] 21
#    [OK] [22/178] 22
#    [OK] [23/178] 23
#    [OK] [24/178] 24
#    [OK] [25/178] 25
#    [OK] [26/178] 26
#    [OK] [27/178] 27
#    [OK] [28/178] 28
#    [OK] [29/178] 29
#    [OK] [30/178] 30
#    [OK] [31/178] 31
#    [OK] [32/178] 32
#    [OK] [33/178] 33
#    [OK] [34/178] 34
#    [OK] [35/178] 35
#    [OK] [36/178] 36
#    [OK] [37/178] 37
#    [OK] [38/178] 38
#    [OK] [39/178] 39
#    [OK] [40/178] 40
#    [OK] [41/178] 41
#    [OK] [42/178] 42
#    [OK] [43/178] 43
#    [OK] [44/178] 44
#    [OK] [45/178] 45
#    [OK] [46/178] 46
#    [OK] [47/178] 47
#    [OK] [48/178] 48
#    [OK] [49/178] 49
#    [OK] [50/178] 50
#    [OK] [51/178] 51
#    [OK] [52/178] 52
#    [OK] [53/178] 53
#    [OK] [54/178] 54
#    [OK] [55/178] 55
#    [OK] [56/178] 56
#    [OK] [57/178] 57
#    [OK] [58/178] 58
#    [OK] [59/178] 59
#    [OK] [60/178] 60
#    [OK] [61/178] 61
#    [OK] [62/178] 62
#    [OK] [63/178] 63
#    [OK] [64/178] 64
#    [OK] [65/178] 65
#    [OK] [66/178] 66
#    [OK] [67/178] 67
#    [OK] [68/178] 68
#    [OK] [69/178] 69
#    [OK] [70/178] 70
#    [OK] [71/178] 71
#    [OK] [72/178] 72
#    [OK] [73/178] 73
#    [OK] [74/178] 74
#    [OK] [75/178] 75
#    [OK] [76/178] 76
#    [OK] [77/178] 77
#    [OK] [78/178] 78
#    [OK] [79/178] 79
#    [OK] [80/178] 80
#    [OK] [81/178] 81
#    [OK] [82/178] 82
#    [OK] [83/178] 83
#    [OK] [84/178] 84
#    [OK] [85/178] 85
#    [OK] [86/178] 86
#    [OK] [87/178] 87
#    [OK] [88/178] 88
#    [OK] [89/178] 89
#    [OK] [90/178] 90
#    [OK] [91/178] 91
#    [OK] [92/178] 92
#    [OK] [93/178] 93
#    [OK] [94/178] 94
#    [OK] [95/178] 95
#    [OK] [96/178] 96
#    [OK] [97/178] 97
#    [OK] [98/178] 98
#    [OK] [99/178] 99
#    [OK] [100/178] 100
#    [OK] [101/178] 101
#    [OK] [102/178] 102
#    [OK] [103/178] 103
#    [OK] [104/178] 104
#    [OK] [105/178] 105
#    [OK] [106/178] 106
#    [OK] [107/178] 107
#    [OK] [108/178] 108
#    [OK] [109/178] 109
#    [OK] [110/178] 110
#    [OK] [111/178] 111
#    [OK] [112/178] 112
#    [OK] [113/178] 113
#    [OK] [114/178] 114
#    [OK] [115/178] 115
#    [OK] [116/178] 116
#    [OK] [117/178] 117
#    [OK] [118/178] 118
#    [OK] [119/178] 119
#    [OK] [120/178] 120
#    [OK] [121/178] 121
#    [OK] [122/178] 122
#    [OK] [123/178] 123
#    [OK] [124/178] 124
#    [OK] [125/178] 125
#    [OK] [126/178] 126
#    [OK] [127/178] 127
#    [OK] [128/178] 128
#    [OK] [129/178] 129
#    [OK] [130/178] 130
#    [OK] [131/178] 131
#    [OK] [132/178] 132
#    [OK] [133/178] 133
#    [OK] [134/178] 134
#    [OK] [135/178] 135
#    [OK] [136/178] 136
#    [OK] [137/178] 137
#    [OK] [138/178] 138
#    [OK] [139/178] 139
#    [OK] [140/178] 140
#    [OK] [141/178] 141
#    [OK] [142/178] 142
#    [OK] [143/178] 143
#    [OK] [144/178] 144
#    [OK] [145/178] 145
#    [OK] [146/178] 146
#    [OK] [147/178] 147
#    [OK] [148/178] 148
#    [OK] [149/178] 149
#    [OK] [150/178] 150
#    [OK] [151/178] 151
#    [OK] [152/178] 152
#    [OK] [153/178] 153
#    [OK] [154/178] 154
#    [OK] [155/178] 155
#    [OK] [156/178] 156
#    [OK] [157/178] 157
#    [OK] [158/178] 158
#    [OK] [159/178] 159
#    [OK] [160/178] 160
#    [OK] [161/178] 161
#    [OK] [162/178] 162
#    [OK] [163/178] 163
#    [OK] [164/178] 164
#    [OK] [165/178] 165
#    [OK] [166/178] 166
#    [OK] [167/178] 167
#    [OK] [168/178] 168
#    [OK] [169/178] 169
#    [OK] [170/178] 170
#    [OK] [171/178] 171
#    [OK] [172/178] 172
#    [OK] [173/178] 173
#    [OK] [174/178] 174
#    [OK] [175/178] 175
#    [OK] [176/178] 176
#    [OK] [177/178] 177
#    [OK] [178/178] 178
# ============================================================
# [SUMMARY] Created: 178
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] common-masters.Department
#    Tenant: old
#    Records: 13
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Department
# ============================================================
#    [OK] [1/13] DEPT_10
#    [OK] [2/13] DEPT_13
#    [OK] [3/13] DEPT_35
#    [OK] [4/13] DEPT_25
#    [OK] [5/13] DEPT_9
#    [OK] [6/13] DEPT_8
#    [OK] [7/13] DEPT_7
#    [OK] [8/13] DEPT_6
#    [OK] [9/13] DEPT_5
#    [OK] [10/13] DEPT_4
#    [OK] [11/13] DEPT_3
#    [OK] [12/13] DEPT_2
#    [OK] [13/13] DEPT_1
# ============================================================
# [SUMMARY] Created: 13
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] common-masters.Designation
#    Tenant: old
#    Records: 29
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [OK] [1/29] DESIG_17
#    [OK] [2/29] DESIG_20
#    [OK] [3/29] DESIG_05
#    [OK] [4/29] DESIG_06
#    [OK] [5/29] DESIG_18
#    [OK] [6/29] DESIG_12
#    [OK] [7/29] DESIG_14
#    [OK] [8/29] COMM
#    [OK] [9/29] DESIG_15
#    [OK] [10/29] AO
#    [OK] [11/29] DESIG_47
#    [OK] [12/29] DESIG_19
#    [OK] [13/29] DESIG_08
#    [OK] [14/29] DESIG_22
#    [OK] [15/29] DESIG_04
#    [OK] [16/29] DESIG_24
#    [OK] [17/29] DESIG_09
#    [OK] [18/29] DESIG_1001
#    [OK] [19/29] DESIG_10
#    [OK] [20/29] DESIG_13
#    [OK] [21/29] DESIG_07
#    [OK] [22/29] DESIG_01
#    [OK] [23/29] DESIG_16
#    [OK] [24/29] DESIG_58
#    [OK] [25/29] DESIG_03
#    [OK] [26/29] DESIG_11
#    [OK] [27/29] DESIG_23
#    [OK] [28/29] DESIG_21
#    [OK] [29/29] DESIG_02
# ============================================================
# [SUMMARY] Created: 29
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] common-masters.GenderType
#    Tenant: old
#    Records: 4
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.GenderType
# ============================================================
#    [OK] [1/4] FEMALE
#    [OK] [2/4] TRANSGENDER
#    [OK] [3/4] MALE
#    [OK] [4/4] OTHERS
# ============================================================
# [SUMMARY] Created: 4
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] common-masters.StateInfo
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.StateInfo
# ============================================================
#    [OK] [1/1] pg
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] egov-hrms.EmployeeStatus
#    Tenant: old
#    Records: 7
#    API URL: http://kong:8000/mdms-v2/v2/_create/egov-hrms.EmployeeStatus
# ============================================================
#    [OK] [1/7] DECEASED
#    [OK] [2/7] TRANSFERRED
#    [OK] [3/7] TERMINATED
#    [OK] [4/7] RETIRED
#    [OK] [5/7] EMPLOYED
#    [OK] [6/7] SUSPENDED
#    [OK] [7/7] RESIGNED
# ============================================================
# [SUMMARY] Created: 7
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] egov-hrms.EmployeeType
#    Tenant: old
#    Records: 5
#    API URL: http://kong:8000/mdms-v2/v2/_create/egov-hrms.EmployeeType
# ============================================================
#    [OK] [1/5] PERMANENT
#    [OK] [2/5] DAILYWAGES
#    [OK] [3/5] DEPUTATION
#    [OK] [4/5] TEMPORARY
#    [OK] [5/5] CONTRACT
# ============================================================
# [SUMMARY] Created: 5
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] egov-hrms.DeactivationReason
#    Tenant: old
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/egov-hrms.DeactivationReason
# ============================================================
#    [OK] [1/2] OTHERS
#    [OK] [2/2] ORDERBYCOMMISSIONER
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] ACCESSCONTROL-ROLES.roles
#    Tenant: old
#    Records: 22
#    API URL: http://kong:8000/mdms-v2/v2/_create/ACCESSCONTROL-ROLES.roles
# ============================================================
#    [OK] [1/22] PGR_VIEWER
#    [OK] [2/22] SUPERVISOR
#    [OK] [3/22] DGRO
#    [OK] [4/22] MDMS_ADMIN
#    [OK] [5/22] REINDEXING_ROLE
#    [OK] [6/22] CSR
#    [OK] [7/22] HRMS_ADMIN
#    [OK] [8/22] SYSTEM
#    [OK] [9/22] ANONYMOUS
#    [OK] [10/22] PGR_LME
#    [OK] [11/22] LOC_ADMIN
#    [OK] [12/22] QA_AUTOMATION
#    [OK] [13/22] WORKFLOW_ADMIN
#    [OK] [14/22] COMMON_EMPLOYEE
#    [OK] [15/22] GRO
#    [OK] [16/22] AUTO_ESCALATE
#    [OK] [17/22] SUPERUSER
#    [EXISTS] [18/22] SUPERVISOR (HTTP 400)
#    [OK] [19/22] CITIZEN
#    [OK] [20/22] EMPLOYEE
#    [OK] [21/22] INTERNAL_MICROSERVICE_ROLE
#    [OK] [22/22] TICKET_REPORT_VIEWER
# ============================================================
# [SUMMARY] Created: 21
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: old
#    Records: 33
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [OK] [1/33] IllegalShopsOnFootPath
#    [OK] [2/33] ParkRequiresMaintenance
#    [OK] [3/33] RequestSprayingOrFoggingOperation
#    [OK] [4/33] NoStreetlight
#    [OK] [5/33] ManholeCoverMissingOrDamaged
#    [OK] [6/33] NoWaterOrElectricityinPublicToilet
#    [OK] [7/33] DamagedOrBlockedFootpath
#    [OK] [8/33] Others
#    [OK] [9/33] StrayAnimals
#    [OK] [10/33] PublicToiletIsDamaged
#    [OK] [11/33] ConstructionMaterialLyingOntheRoad
#    [OK] [12/33] ShortageOfWater
#    [OK] [13/33] OpenDefecation
#    [OK] [14/33] DirtyOrSmellyPublicToilets
#    [OK] [15/33] WaterLoggedRoad
#    [OK] [16/33] BrokenWaterPipeOrLeakage
#    [OK] [17/33] IllegalConstructions
#    [OK] [18/33] NonSweepingOfRoad
#    [OK] [19/33] DirtyWaterSupply
#    [OK] [20/33] BurningOfGarbage
#    [OK] [21/33] WaterPressureisVeryLess
#    [OK] [22/33] IllegalCuttingOfTrees
#    [OK] [23/33] DeadAnimals
#    [OK] [24/33] DamagedGarbageBin
#    [OK] [25/33] IllegalParking
#    [OK] [26/33] DamagedRoad
#    [OK] [27/33] illegalDischargeOfSewage
#    [OK] [28/33] NoWaterSupply
#    [OK] [29/33] StreetLightNotWorking
#    [OK] [30/33] GarbageNeedsTobeCleared
#    [OK] [31/33] BlockOrOverflowingSewage
#    [OK] [32/33] CuttingOrTrimmingOfTreeRequired
#    [OK] [33/33] OverflowingOrBlockedDrain
# ============================================================
# [SUMMARY] Created: 33
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    🔄 Initializing empty citymodule 'Workbench' for root 'old'
#    🔄 Initializing empty citymodule 'PGR' for root 'old'
#    🔄 Initializing empty citymodule 'HRMS' for root 'old'
#
# [UPLOADING] tenant.citymodule
#    Tenant: old
#    Records: 3
#    API URL: http://kong:8000/mdms-v2/v2/_create/tenant.citymodule
# ============================================================
#    [OK] [1/3] Workbench
#    [OK] [2/3] PGR
#    [OK] [3/3] HRMS
# ============================================================
# [SUMMARY] Created: 3
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] tenant.tenants
#    Tenant: old
#    Records: 6
#    API URL: http://kong:8000/mdms-v2/v2/_create/tenant.tenants
# ============================================================
#    [OK] [1/6] pg.dbupdate
#    [OK] [2/6] pg.testupdate
#    [OK] [3/6] statea.g
#    [OK] [4/6] pg
#    [OK] [5/6] pg.cityb
#    [OK] [6/6] pg.citya
# ============================================================
# [SUMMARY] Created: 6
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] DataSecurity.EncryptionPolicy
#    Tenant: old
#    Records: 3
#    API URL: http://kong:8000/mdms-v2/v2/_create/DataSecurity.EncryptionPolicy
# ============================================================
#    [OK] [1/3] 1
#    [OK] [2/3] 2
#    [OK] [3/3] 3
# ============================================================
# [SUMMARY] Created: 3
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] DataSecurity.DecryptionABAC
#    Tenant: old
#    Records: 25
#    API URL: http://kong:8000/mdms-v2/v2/_create/DataSecurity.DecryptionABAC
# ============================================================
#    [OK] [1/25] 1
#    [OK] [2/25] 2
#    [OK] [3/25] 3
#    [OK] [4/25] 4
#    [OK] [5/25] 5
#    [OK] [6/25] 6
#    [OK] [7/25] 7
#    [OK] [8/25] 8
#    [OK] [9/25] 9
#    [OK] [10/25] 10
#    [OK] [11/25] 11
#    [OK] [12/25] 12
#    [OK] [13/25] 13
#    [OK] [14/25] 14
#    [OK] [15/25] 15
#    [OK] [16/25] 16
#    [OK] [17/25] 17
#    [OK] [18/25] 18
#    [OK] [19/25] 19
#    [OK] [20/25] 20
#    [OK] [21/25] 21
#    [OK] [22/25] 22
#    [OK] [23/25] 23
#    [OK] [24/25] 24
#    [OK] [25/25] 25
# ============================================================
# [SUMMARY] Created: 25
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [UPLOADING] DataSecurity.MaskingPatterns
#    Tenant: old
#    Records: 8
#    API URL: http://kong:8000/mdms-v2/v2/_create/DataSecurity.MaskingPatterns
# ============================================================
#    [OK] [1/8] 1
#    [OK] [2/8] 2
#    [OK] [3/8] 3
#    [OK] [4/8] 4
#    [OK] [5/8] 5
#    [OK] [6/8] 6
#    [OK] [7/8] 7
#    [OK] [8/8] 8
# ============================================================
# [SUMMARY] Created: 8
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    📦 Data: 338 records copied, 1 already existed
#    🔧 Copying ID generation formats...
#    ✅ Copied ID formats from 'pg' to 'old' (total: 8)
#    ✅ ID formats: 8 formats copied
#    👤 Creating core admin user...
#    ✅ User 'ADMIN' created with roles: ['SUPERUSER', 'EMPLOYEE']
#    ✅ Admin user created for root 'old'
#    ℹ️  Skipping workflow services for root tenant 'old' (child tenants will get them)
#    🔧 Copying localization messages...
#    ⚠️  Localization copy failed: column "createdtime" of relation "message" does not exist
# LINE 2: ...cale, code, message, tenantid,
#    ✅ Bootstrap complete for 'old'
#
# ✅ Root tenant 'old' bootstrapped successfully
# ✅ Tenant 'old.bat' created successfully!
#
# [UPLOADING] common-masters.StateInfo
#    Tenant: old.bat
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.StateInfo
# ============================================================
#    [OK] [1/1] old.bat
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ StateInfo ensured for 'old.bat'
#    🔧 Adding 'old.bat' to PGR citymodule under root 'old'
#    ✅ PGR: Added 'old.bat' to existing citymodule
#    🔧 Adding 'old.bat' to HRMS citymodule under root 'old'
#    ✅ HRMS: Added 'old.bat' to existing citymodule
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 13
#      10 loader.login(username=USERNAME, password=PASSWORD, tenant_id=TENANT_ID)
#      12 # Create target tenant if it doesn't exist (also enables PGR & HRMS modules)
# ---> 13 loader.create_tenant(TARGET_TENANT, "My Tenant", users=[
#      14       {"username": "ADMIN", "password": "eGov@123", "name": "Admin",
#      15        "roles": ["SUPERUSER", "EMPLOYEE"]}
#      16   ])
#      18 loader.login(username=USERNAME, password=PASSWORD, tenant_id=TARGET_TENANT)
#      20 # Resolve template directory reliably regardless of notebook launch directory
#
# File /home/jovyan/work/dataloader/dataloader/crs_loader.py:238, in CRSLoader.create_tenant(self, tenant_code, display_name, enable_modules, users)
#     235     self._enable_module_for_tenant(tenant_code, module)
#     237 # Copy workflow business services to child tenant (PGR needs this)
# --> 238 self._copy_workflow_services_to_child_tenant(tenant_code, root_tenant)
#     240 # Create users for the tenant
#     241 if users:
#
# AttributeError: 'CRSLoader' object has no attribute '_copy_workflow_services_to_child_tenant'

# %%
# Phase 2a - Generate Boundary Template
# Creates hierarchy definition and downloads an Excel template to fill

BOUNDARY_HIERARCHY = "ADMIN"  # or "ADMIN" 
BOUNDARY_LEVELS = ["State", "District", "Locality"]  # Top to bottom

template_path = loader.load_hierarchy(
    name=BOUNDARY_HIERARCHY,
    levels=BOUNDARY_LEVELS,
    target_tenant=TARGET_TENANT,
    output_dir="upload"
)
print(f"Template saved to: {template_path}")
# Fill the template with your boundary data, then run Phase 2b below
# Out:
# ============================================================
# PHASE 2a: BOUNDARY HIERARCHY & TEMPLATE
# ============================================================
# Tenant: old.bat
# Hierarchy: ADMIN
# Levels: State -> District -> Locality
#
# [1/4] Building hierarchy definition...
#    Created 3 level definitions
#
# [2/4] Creating hierarchy...
#
# ✅ [SUCCESS] Boundary hierarchy created
#    Tenant: old.bat
#    Hierarchy Type: ADMIN
#    Levels: 3
#    Hierarchy created successfully
#
# [3/4] Generating template...
#
# [UPLOADING] project-factory.CampaignType
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/project-factory.CampaignType
# ============================================================
#    [EXISTS] [1/1] BOUNDARY_SETUP (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#    ✅ Ensured campaign type schema exists
#
# ✅ Template generation initiated
#    Task ID: 377f649f-2196-454d-9c6c-593cfcceb883
#    Status: inprogress
#
# [4/4] Waiting for template...
#
# ⏳ Polling for template generation (max 30 attempts)...
#    Attempt 1/30: Status = inprogress
#    Attempt 2/30: Status = failed
#
# ❌ Template generation failed
#    Error: No error details provided
#    Additional Details: {
#   "error": {
#     "code": "FETCHING_COLUMN_ERROR",
#     "status": 400,
#     "message": "Error fetching Column Headers From Schema",
#     "description": "Error fetching column Headers From Schema (either boundary code column not found or given  Campaign Type not found in schema) Check logs"
#   }
# }
#
# 📋 Full resource response:
#    {
#   "id": "377f649f-2196-454d-9c6c-593cfcceb883",
#   "status": "failed",
#   "hierarchytype": "ADMIN",
#   "locale": "en_IN",
#   "auditDetails": {
#     "lastModifiedTime": "1774875695753",
#     "createdTime": "1774875695753",
#     "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#     "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a"
#   },
#   "tenantId": "old.bat",
#   "additionalDetails": {
#     "error": {
#       "code": "FETCHING_COLUMN_ERROR",
#       "status": 400,
#       "message": "Error fetching Column Headers From Schema",
#       "description": "Error fetching column Headers From Schema (either boundary code column not found or given  Campaign Type not found in schema) Check logs"
#     }
#   },
#   "fileStoreid": null,
#   "referenceId": null
# }
#    ❌ Template generation failed
#    🔍 Error details: {'code': 'FETCHING_COLUMN_ERROR', 'status': 400, 'message': 'Error fetching Column Headers From Schema', 'description': 'Error fetching column Headers From Schema (either boundary code column not found or given  Campaign Type not found in schema) Check logs'}
#    💡 SOLUTION: Create Excel manually with these columns:
#       Code | Name | Type | Parent
#    📝 Save as boundaries.xlsx and proceed to Phase 2b
# Template saved to: None

# %%
# Phase 2b - Load Boundaries from filled template
# Use the template path from Phase 2a, or specify your own filled boundary file

BOUNDARY_FILE = str(TEMPLATE_DIR / "Boundary_Master (3).xlsx")  # Or: "upload/boundary_filled_statea_REVENUE.xlsx"

loader.load_boundaries(BOUNDARY_FILE, target_tenant=TARGET_TENANT, hierarchy_type=BOUNDARY_HIERARCHY)
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary_Master (3).xlsx
# Hierarchy: ADMIN
#
# [1/2] Uploading boundary file...
#
# 📤 Uploading file: Boundary_Master (3).xlsx
# ✅ File uploaded successfully!
#    FileStore ID: 61a6684a-c54c-48d7-8f99-f2ba0e10b0ac
#    FileStore ID: 61a6684a-c54c-48d7-8f99-f2ba0e10b0ac
#
# [2/2] Processing boundary data...
#
# 📖 Reading boundary data from: /home/jovyan/work/dataloader/dataloader/templates/Boundary_Master (3).xlsx
#    Found 88 boundary records
#    Columns: ['code', 'name', 'boundaryType', 'parentCode']
#    Hierarchy: State → District → Locality
#    Using standard format (code, boundaryType, parentCode)
#    Boundary types match hierarchy - no mapping needed
#    ⚠️ Boundary exists: PB
#    ⚠️ Relationship exists: PB
#    ⚠️ Boundary exists: PB_AMR
#    ⚠️ Relationship exists: PB_AMR
#    ⚠️ Boundary exists: PB_AMR_AJN
#    ⚠️ Relationship exists: PB_AMR_AJN
#    ⚠️ Boundary exists: PB_AMR_BBK
#    ⚠️ Relationship exists: PB_AMR_BBK
#    ⚠️ Boundary exists: PB_AMR_AM1
#    ⚠️ Relationship exists: PB_AMR_AM1
#    ⚠️ Boundary exists: PB_AMR_AM2
#    ⚠️ Relationship exists: PB_AMR_AM2
#    ⚠️ Boundary exists: PB_LDH
#    ⚠️ Relationship exists: PB_LDH
#    ⚠️ Boundary exists: PB_LDH_LDH
#    ⚠️ Relationship exists: PB_LDH_LDH
#    ⚠️ Boundary exists: PB_LDH_KHN
#    ⚠️ Relationship exists: PB_LDH_KHN
#    ⚠️ Boundary exists: PB_LDH_SAM
#    ⚠️ Relationship exists: PB_LDH_SAM
#    ⚠️ Boundary exists: PB_LDH_JAG
#    ⚠️ Relationship exists: PB_LDH_JAG
#    ⚠️ Boundary exists: PB_JAL
#    ⚠️ Relationship exists: PB_JAL
#    ⚠️ Boundary exists: PB_JAL_JAL
#    ⚠️ Relationship exists: PB_JAL_JAL
#    ⚠️ Boundary exists: PB_JAL_NAK
#    ⚠️ Relationship exists: PB_JAL_NAK
#    ⚠️ Boundary exists: PB_JAL_PHG
#    ⚠️ Relationship exists: PB_JAL_PHG
#    ⚠️ Boundary exists: PB_PTL
#    ⚠️ Relationship exists: PB_PTL
#    ⚠️ Boundary exists: PB_PTL_PTL
#    ⚠️ Relationship exists: PB_PTL_PTL
#    ⚠️ Boundary exists: PB_PTL_RAJ
#    ⚠️ Relationship exists: PB_PTL_RAJ
#    ⚠️ Boundary exists: PB_PTL_NAB
#    ⚠️ Relationship exists: PB_PTL_NAB
#    ⚠️ Boundary exists: PB_PTL_SAM
#    ⚠️ Relationship exists: PB_PTL_SAM
#    ⚠️ Boundary exists: PB_BTH
#    ⚠️ Relationship exists: PB_BTH
#    ⚠️ Boundary exists: PB_BTH_BTH
#    ⚠️ Relationship exists: PB_BTH_BTH
#    ⚠️ Boundary exists: PB_BTH_TAL
#    ⚠️ Relationship exists: PB_BTH_TAL
#    ⚠️ Boundary exists: PB_BTH_RAM
#    ⚠️ Relationship exists: PB_BTH_RAM
#    ⚠️ Boundary exists: PB_FZK
#    ⚠️ Relationship exists: PB_FZK
#    ⚠️ Boundary exists: PB_FZK_FZK
#    ⚠️ Relationship exists: PB_FZK_FZK
#    ⚠️ Boundary exists: PB_FZK_ABO
#    ⚠️ Relationship exists: PB_FZK_ABO
#    ⚠️ Boundary exists: PB_SNG
#    ⚠️ Relationship exists: PB_SNG
#    ⚠️ Boundary exists: PB_SNG_SNG
#    ⚠️ Relationship exists: PB_SNG_SNG
#    ⚠️ Boundary exists: PB_SNG_AHM
#    ⚠️ Relationship exists: PB_SNG_AHM
#    ⚠️ Boundary exists: PB_SNG_BHW
#    ⚠️ Relationship exists: PB_SNG_BHW
#    ⚠️ Boundary exists: PB_SNG_MLK
#    ⚠️ Relationship exists: PB_SNG_MLK
#    ⚠️ Boundary exists: PB_HSP
#    ⚠️ Relationship exists: PB_HSP
#    ⚠️ Boundary exists: PB_HSP_HSP
#    ✅ Created relationship: PB_HSP_HSP [Locality] (parent: PB_HSP)
#    ⚠️ Boundary exists: PB_HSP_DAS
#    ⚠️ Relationship exists: PB_HSP_DAS
#    ⚠️ Boundary exists: PB_HSP_GAR
#    ✅ Created relationship: PB_HSP_GAR [Locality] (parent: PB_HSP)
#    ⚠️ Boundary exists: PB_GDS
#    ⚠️ Relationship exists: PB_GDS
#    ⚠️ Boundary exists: PB_GDS_GDS
#    ⚠️ Relationship exists: PB_GDS_GDS
#    ⚠️ Boundary exists: PB_GDS_BTL
#    ⚠️ Relationship exists: PB_GDS_BTL
#    ⚠️ Boundary exists: PB_GDS_DBN
#    ⚠️ Relationship exists: PB_GDS_DBN
#    ⚠️ Boundary exists: PB_KPT
#    ⚠️ Relationship exists: PB_KPT
#    ⚠️ Boundary exists: PB_KPT_KPT
#    ⚠️ Relationship exists: PB_KPT_KPT
#    ⚠️ Boundary exists: PB_KPT_BHL
#    ⚠️ Relationship exists: PB_KPT_BHL
#    ⚠️ Boundary exists: PB_KPT_PHG
#    ⚠️ Relationship exists: PB_KPT_PHG
#    ⚠️ Boundary exists: PB_MOG
#    ⚠️ Relationship exists: PB_MOG
#    ⚠️ Boundary exists: PB_MOG_MOG
#    ⚠️ Relationship exists: PB_MOG_MOG
#    ⚠️ Boundary exists: PB_MOG_BAG
#    ⚠️ Relationship exists: PB_MOG_BAG
#    ⚠️ Boundary exists: PB_FGS
#    ⚠️ Relationship exists: PB_FGS
#    ⚠️ Boundary exists: PB_FGS_FGS
#    ⚠️ Relationship exists: PB_FGS_FGS
#    ⚠️ Boundary exists: PB_FGS_AML
#    ⚠️ Relationship exists: PB_FGS_AML
#    ⚠️ Boundary exists: PB_FGS_BSP
#    ⚠️ Relationship exists: PB_FGS_BSP
#    ⚠️ Boundary exists: PB_RPN
#    ✅ Created relationship: PB_RPN [District] (parent: PB)
#    ⚠️ Boundary exists: PB_RPN_RPN
#    ✅ Created relationship: PB_RPN_RPN [Locality] (parent: PB_RPN)
#    ⚠️ Boundary exists: PB_RPN_ANS
#    ✅ Created relationship: PB_RPN_ANS [Locality] (parent: PB_RPN)
#    ⚠️ Boundary exists: PB_SAS
#    ⚠️ Relationship exists: PB_SAS
#    ⚠️ Boundary exists: PB_SAS_MOH
#    ⚠️ Relationship exists: PB_SAS_MOH
#    ⚠️ Boundary exists: PB_SAS_DBS
#    ⚠️ Relationship exists: PB_SAS_DBS
#    ⚠️ Boundary exists: PB_SAS_KHR
#    ⚠️ Relationship exists: PB_SAS_KHR
#    ⚠️ Boundary exists: PB_SBS
#    ⚠️ Relationship exists: PB_SBS
#    ⚠️ Boundary exists: PB_SBS_NWS
#    ⚠️ Relationship exists: PB_SBS_NWS
#    ⚠️ Boundary exists: PB_SBS_BLC
#    ⚠️ Relationship exists: PB_SBS_BLC
#    ⚠️ Boundary exists: PB_SBS_BNG
#    ⚠️ Relationship exists: PB_SBS_BNG
#    ⚠️ Boundary exists: PB_TRN
#    ⚠️ Relationship exists: PB_TRN
#    ⚠️ Boundary exists: PB_TRN_TRN
#    ⚠️ Relationship exists: PB_TRN_TRN
#    ⚠️ Boundary exists: PB_TRN_BHK
#    ⚠️ Relationship exists: PB_TRN_BHK
#    ⚠️ Boundary exists: PB_TRN_PTT
#    ⚠️ Relationship exists: PB_TRN_PTT
#    ⚠️ Boundary exists: PB_BRN
#    ⚠️ Relationship exists: PB_BRN
#    ⚠️ Boundary exists: PB_BRN_BRN
#    ⚠️ Relationship exists: PB_BRN_BRN
#    ⚠️ Boundary exists: PB_BRN_TPA
#    ⚠️ Relationship exists: PB_BRN_TPA
#    ⚠️ Boundary exists: PB_MNS
#    ⚠️ Relationship exists: PB_MNS
#    ⚠️ Boundary exists: PB_MNS_MNS
#    ⚠️ Relationship exists: PB_MNS_MNS
#    ⚠️ Boundary exists: PB_MNS_BDR
#    ⚠️ Relationship exists: PB_MNS_BDR
#    ⚠️ Boundary exists: PB_MNS_SRD
#    ⚠️ Relationship exists: PB_MNS_SRD
#    ⚠️ Boundary exists: PB_FRP
#    ⚠️ Relationship exists: PB_FRP
#    ⚠️ Boundary exists: PB_FRP_FRP
#    ⚠️ Relationship exists: PB_FRP_FRP
#    ⚠️ Boundary exists: PB_FRP_ZRA
#    ⚠️ Relationship exists: PB_FRP_ZRA
#    ⚠️ Boundary exists: PB_FRP_GUR
#    ⚠️ Relationship exists: PB_FRP_GUR
#    ⚠️ Boundary exists: PB_MKT
#    ✅ Created relationship: PB_MKT [District] (parent: PB)
#    ⚠️ Boundary exists: PB_MKT_MKT
#    ✅ Created relationship: PB_MKT_MKT [Locality] (parent: PB_MKT)
#    ⚠️ Boundary exists: PB_MKT_MLT
#    ✅ Created relationship: PB_MKT_MLT [Locality] (parent: PB_MKT)
#    ⚠️ Boundary exists: PB_MKT_GDW
#    ✅ Created relationship: PB_MKT_GDW [Locality] (parent: PB_MKT)
#    ⚠️ Boundary exists: PB_FRD
#    ✅ Created relationship: PB_FRD [District] (parent: PB)
#    ⚠️ Boundary exists: PB_FRD_FRD
#    ✅ Created relationship: PB_FRD_FRD [Locality] (parent: PB_FRD)
#    ⚠️ Boundary exists: PB_FRD_KTK
#    ✅ Created relationship: PB_FRD_KTK [Locality] (parent: PB_FRD)
#    ⚠️ Boundary exists: PB_FRD_JTN
#    ✅ Created relationship: PB_FRD_JTN [Locality] (parent: PB_FRD)
#    ⚠️ Boundary exists: PB_PTK
#    ⚠️ Relationship exists: PB_PTK
#    ⚠️ Boundary exists: PB_PTK_PTK
#    ⚠️ Relationship exists: PB_PTK_PTK
#    ⚠️ Boundary exists: PB_PTK_DNN
#    ⚠️ Relationship exists: PB_PTK_DNN
#
# ✅ Boundary processing completed!
#    Boundaries created: 88
#    Relationships created: 88
#
#    Status: completed
# {'status': 'completed',
#  'boundaries_created': 88,
#  'relationships_created': 88,
#  'errors': []}

# %%
# Phase 3 - Common Masters
loader.load_common_masters(str(TEMPLATE_DIR / "Common and Complaint Master (3).xlsx"), target_tenant=ROOT_TENANT)
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master (3).xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: old
#    ✅ Found 15 department(s)
# 📥 Fetching designations from MDMS for tenant: old
#    ✅ Found 31 designation(s)
#    Creating 2 designations...
#
# [UPLOADING] common-masters.Designation
#    Tenant: old
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [OK] [1/2] DESIG_1004
#    [OK] [2/2] DESIG_1005
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: /home/jovyan/work/dataloader/dataloader/templates/Common and Complaint Master (3).xlsx
#    Sheet: Designation
#    ⚠️  Sheet 'Designation' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: old
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: old
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [EXISTS] [1/1] WaterNotComing (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: /home/jovyan/work/dataloader/dataloader/templates/Common and Complaint Master (3).xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: old
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ⚠️ Batch 1/1: 2 messages already exist
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 2
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created: 2
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'departments': None,
#  'designations': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'complaint_types': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []}}

# %%
# Phase 4 - Employees
loader.load_employees(str(TEMPLATE_DIR / "Employee_Master_Dynamic_statea_fixed (1).xlsx"), target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea_fixed (1).xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: old.bat
#    ✅ Found 15 department(s)
# 📥 Fetching designations from MDMS for tenant: old.bat
#    ✅ Found 33 designation(s)
# 📥 Fetching roles from MDMS for tenant: old.bat
#    ✅ Found 21 role(s) from MDMS
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: old.bat
#    ✅ Found 21 existing roles in MDMS
#    ✅ All 20 required roles already exist in MDMS
#
# ============================================================
# [UPLOADING] HRMS Employees
#    Tenant: old.bat
#    Records: 1
#    API URL: http://kong:8000/egov-hrms/employees/_create
# ============================================================
#    [OK] [1/1] DEEPAK - Created
#    [✓] [1/1] DEEPAK - Password updated
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Password Updated: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: /home/jovyan/work/dataloader/dataloader/templates/Employee_Master_Dynamic_statea_fixed (1).xlsx
#    Sheet: Employee Master
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# ────────────────────────────────────────
# Employees Summary:
#    Created: 1
#    Already existed: 0
#    Failed: 0
# ────────────────────────────────────────
# {'created': 1, 'exists': 0, 'failed': 0, 'errors': [], 'password_updated': 1}

# %% [markdown]
# ---
#
# ## Phase 5: Localizations (Optional)
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations (Optional)
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
loader.load_localizations(str(TEMPLATE_DIR / "localization.xlsx"), target_tenant=ROOT_TENANT)

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     str(TEMPLATE_DIR / "localization.xlsx"),
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )
# Out:
# ============================================================
# PHASE 5: LOCALIZATIONS
# ============================================================
# File: localization.xlsx
#
# [1/2] Reading localization data...
#    Found 45143 messages
#    - en_IN: 45143 messages
#
# [2/2] Uploading localization messages...
#
# [UPLOADING] Localization Messages
#    Tenant: old
#    Total Messages: 45143
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 45143 messages in batches of 500...
#       ⚠️ Batch 1/91: 500 messages already exist
#       ⚠️ Batch 2/91: 500 messages already exist
#       ⚠️ Batch 3/91: 500 messages already exist
#       ⚠️ Batch 4/91: 500 messages already exist
#       ⚠️ Batch 5/91: 500 messages already exist
#       ⚠️ Batch 6/91: 500 messages already exist
#       ⚠️ Batch 7/91: 500 messages already exist
#       ⚠️ Batch 8/91: 500 messages already exist
#       ⚠️ Batch 9/91: 500 messages already exist
#       ⚠️ Batch 10/91: 500 messages already exist
#       ⚠️ Batch 11/91: 500 messages already exist
#       ⚠️ Batch 12/91: 500 messages already exist
#       ⚠️ Batch 13/91: 500 messages already exist
#       ⚠️ Batch 14/91: 500 messages already exist
#       ⚠️ Batch 15/91: 500 messages already exist
#       ⚠️ Batch 16/91: 500 messages already exist
#       ⚠️ Batch 17/91: 500 messages already exist
#       ⚠️ Batch 18/91: 500 messages already exist
#       ⚠️ Batch 19/91: 500 messages already exist
#       ⚠️ Batch 20/91: 500 messages already exist
#       ⚠️ Batch 21/91: 500 messages already exist
#       ⚠️ Batch 22/91: 500 messages already exist
#       ⚠️ Batch 23/91: 500 messages already exist
#       ⚠️ Batch 24/91: 500 messages already exist
#       ✅ Batch 25/91: 500 messages uploaded
#       ✅ Batch 26/91: 500 messages uploaded
#       ⚠️ Batch 27/91: 500 messages already exist
#       ⚠️ Batch 28/91: 500 messages already exist
#       ⚠️ Batch 29/91: 500 messages already exist
#       ⚠️ Batch 30/91: 500 messages already exist
#       ⚠️ Batch 31/91: 500 messages already exist
#       ⚠️ Batch 32/91: 500 messages already exist
#       ✅ Batch 33/91: 500 messages uploaded
#       ⚠️ Batch 34/91: 500 messages already exist
#       ⚠️ Batch 35/91: 500 messages already exist
#       ⚠️ Batch 36/91: 500 messages already exist
#       ⚠️ Batch 37/91: 500 messages already exist
#       ⚠️ Batch 38/91: 500 messages already exist
#       ⚠️ Batch 39/91: 500 messages already exist
#       ✅ Batch 40/91: 500 messages uploaded
#       ✅ Batch 41/91: 500 messages uploaded
#       ⚠️ Batch 42/91: 500 messages already exist
#       ⚠️ Batch 43/91: 500 messages already exist
#       ✅ Batch 44/91: 500 messages uploaded
#       ✅ Batch 45/91: 500 messages uploaded
#       ⚠️ Batch 46/91: 500 messages already exist
#       ⚠️ Batch 47/91: 500 messages already exist
#       ⚠️ Batch 48/91: 500 messages already exist
#       ⚠️ Batch 49/91: 500 messages already exist
#       ⚠️ Batch 50/91: 500 messages already exist
#       ⚠️ Batch 51/91: 500 messages already exist
#       ⚠️ Batch 52/91: 500 messages already exist
#       ⚠️ Batch 53/91: 500 messages already exist
#       ⚠️ Batch 54/91: 500 messages already exist
#       ⚠️ Batch 55/91: 500 messages already exist
#       ⚠️ Batch 56/91: 500 messages already exist
#       ⚠️ Batch 57/91: 500 messages already exist
#       ⚠️ Batch 58/91: 500 messages already exist
#       ⚠️ Batch 59/91: 500 messages already exist
#       ⚠️ Batch 60/91: 500 messages already exist
#       ⚠️ Batch 61/91: 500 messages already exist
#       ⚠️ Batch 62/91: 500 messages already exist
#       ⚠️ Batch 63/91: 500 messages already exist
#       ⚠️ Batch 64/91: 500 messages already exist
#       ⚠️ Batch 65/91: 500 messages already exist
#       ⚠️ Batch 66/91: 500 messages already exist
#       ⚠️ Batch 67/91: 500 messages already exist
#       ⚠️ Batch 68/91: 500 messages already exist
#       ⚠️ Batch 69/91: 500 messages already exist
#       ✅ Batch 70/91: 500 messages uploaded
#       ✅ Batch 71/91: 500 messages uploaded
#       ⚠️ Batch 72/91: 500 messages already exist
#       ⚠️ Batch 73/91: 500 messages already exist
#       ⚠️ Batch 74/91: 500 messages already exist
#       ⚠️ Batch 75/91: 500 messages already exist
#       ⚠️ Batch 76/91: 500 messages already exist
#       ⚠️ Batch 77/91: 500 messages already exist
#       ⚠️ Batch 78/91: 500 messages already exist
#       ⚠️ Batch 79/91: 500 messages already exist
#       ⚠️ Batch 80/91: 500 messages already exist
#       ⚠️ Batch 81/91: 500 messages already exist
#       ⚠️ Batch 82/91: 500 messages already exist
#       ⚠️ Batch 83/91: 500 messages already exist
#       ⚠️ Batch 84/91: 500 messages already exist
#       ⚠️ Batch 85/91: 500 messages already exist
#       ⚠️ Batch 86/91: 500 messages already exist
#       ⚠️ Batch 87/91: 500 messages already exist
#       ⚠️ Batch 88/91: 500 messages already exist
#       ⚠️ Batch 89/91: 500 messages already exist
#       ⚠️ Batch 90/91: 500 messages already exist
#       ⚠️ Batch 91/91: 143 messages already exist
# ============================================================
# [SUMMARY] Created: 4500
# [SUMMARY] Already Exists: 40643
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Localizations Summary:
#    Created: 4500
#    Already existed: 40643
#    Failed: 0
# ────────────────────────────────────────
# {'messages': {'created': 4500,
#   'exists': 40643,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []},
#  'stateinfo': None}

# %% [markdown]
# ---
#
# ## Phase 6: Workflow Configuration
#
# Configure the PGR complaint workflow state machine from a JSON file. This defines the complaint lifecycle:
# - **APPLY** → Citizen/CSR creates complaint
# - **PENDINGFORASSIGNMENT** → GRO assigns to field worker
# - **PENDINGATLME** → Field worker resolves or reassigns
# - **RESOLVED/REJECTED** → Terminal states with rating option
#
# **Template:** Use `../default-data-handler/src/main/resources/PgrWorkflowConfig.json` as a starting point.
#
# The JSON file should have a `BusinessServices` array. Use `{tenantid}` as a placeholder - it will be replaced with your target tenant.

# %%
# Phase 6 - Workflow
# Loads the PGR complaint workflow state machine from JSON file

# Default PGR workflow template (copy and modify as needed)
WORKFLOW_JSON = str(TEMPLATE_DIR / "PgrWorkflowConfig.json")

loader.load_workflow(WORKFLOW_JSON, target_tenant=ROOT_TENANT)
# Out:
# ============================================================
# PHASE 6: WORKFLOW
# ============================================================
# File: PgrWorkflowConfig.json
# Tenant: old
# Business Service: PGR
#
# [1/3] Loading workflow config from JSON...
#    Loaded 11 states
#
# [2/3] Checking for existing workflow...
#    No existing workflow found
#
# [3/3] Creating workflow...
#    Workflow created successfully (11 states)
# {'status': 'created', 'error': None, 'states': 11}

# %% [markdown]
# ---
#
# ## Rollback / Delete Data
#
# Use these cells to undo data loading. Run only what you need to rollback.

# %%
# Rollback Phase 2 - Delete Boundaries
# Deletes all boundary entities and relationships for the tenant
loader.delete_boundaries(TARGET_TENANT)

# %%
# Rollback Phase 3 - Delete Common Masters
# Deletes departments, designations, and complaint types
loader.rollback_common_masters(TARGET_TENANT)

# %%
# Rollback Phase 1 - Delete Tenant Config
# Deletes tenant and branding configuration
loader.rollback_tenant(TARGET_TENANT)

# %%
# Delete specific MDMS schema data (granular control)
loader.delete_mdms("common-masters.Department", TARGET_TENANT)
loader.delete_mdms("common-masters.Designation", TARGET_TENANT)
loader.delete_mdms("RAINMAKER-PGR.ServiceDefs", TARGET_TENANT)

# %%
# FULL RESET - Delete everything (MDMS + Boundaries)
# WARNING: This deletes ALL data for the tenant!
loader.full_reset("REVENUE", TARGET_TENANT)

# %% [markdown]
# **Note:** Employees (Phase 4) cannot be deleted via API - they are managed in HRMS and must be deactivated manually if needed.
