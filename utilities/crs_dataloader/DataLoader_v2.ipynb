# %% [markdown]
# # CRS Data Loader v2
#
# Simple 5-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
# 5. **Localizations** (Optional) - Bulk load translations for new languages
#
# ---

# %%
import warnings
import pandas as pd
import requests
from openpyxl import load_workbook
from crs_loader import CRSLoader

# %%
# Configuration - Edit these values
URL = "https://chakshu-digit.egov.theflywheel.in"
USERNAME = "ADMIN"
PASSWORD = "eGov@123"
TENANT_ID = "statea"  # Root tenant for login
TARGET_TENANT = "statea"  # Target tenant for data (can be child like "statea.citya")

loader = CRSLoader(URL)
loader.login(username=USERNAME, password=PASSWORD, tenant_id=TENANT_ID)
# Out:
# ✅ Authentication successful!
#    User: ADMIN
#    Name: Admin User
#    Tenant: statea
#    Token: 78ee241e-a88b-4131-8...
# True

# %%
# Phase 1 - Tenant & Branding
loader.load_tenant("templates/Tenant And Branding Master.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 1: TENANT & BRANDING
# ============================================================
# File: Tenant And Branding Master.xlsx
#
# [1/3] Creating tenants...
#
# [UPLOADING] tenant.tenants
#    Tenant: statea
#    Records: 1
#    API URL: https://chakshu-digit.egov.theflywheel.in/mdms-v2/v2/_create/tenant.tenants
# ============================================================
#    [EXISTS] [1/1] pg.citya (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Tenant And Branding Master.xlsx
#    Sheet: Tenant Info
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# [2/3] Creating branding...
#
# [UPLOADING] tenant.branding
#    Tenant: statea
#    Records: 1
#    API URL: https://chakshu-digit.egov.theflywheel.in/mdms-v2/v2/_create/tenant.branding
# ============================================================
#    [EXISTS] [1/1] statea (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Tenant And Branding Master.xlsx
#    Sheet: Tenant Branding Details
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# [3/3] Creating localizations...
#
# [UPLOADING] Localization Messages
#    Tenant: statea
#    Total Messages: 1
#    API URL: https://chakshu-digit.egov.theflywheel.in/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 1 messages in batches of 500...
#       ✅ Batch 1/1: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Tenant & Branding Summary:
#    Created: 1
#    Already existed: 2
#    Failed: 0
# ────────────────────────────────────────
# {'tenants': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []},
#  'branding': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []},
#  'localization': {'created': 1,
#   'exists': 0,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []}}

# %%
# Phase 2 - Boundaries
loader.load_boundaries("templates/Boundary_Master.xlsx", target_tenant=TARGET_TENANT, hierarchy_type="REVENUE")
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary_Master.xlsx
# Hierarchy: REVENUE
#
# [1/2] Uploading boundary file...
#
# 📤 Uploading file: Boundary_Master.xlsx
# ✅ File uploaded successfully!
#    FileStore ID: 4bae04f4-1096-452c-a539-c58cf157af90
#    FileStore ID: 4bae04f4-1096-452c-a539-c58cf157af90
#
# [2/2] Processing boundary data...
#
# 📖 Reading boundary data from: templates/Boundary_Master.xlsx
#    Found 88 boundary records
#    Columns: ['code', 'name', 'boundaryType', 'parentCode']
#    Hierarchy: State → District → Tehsil
#    Using standard format (code, boundaryType, parentCode)
#    Boundary types match hierarchy - no mapping needed
#    ✅ Created boundary: PB
#    ✅ Created relationship: PB [State] (root)
#    ✅ Created boundary: PB_AMR
#    ✅ Created relationship: PB_AMR [District] (parent: PB)
#    ✅ Created boundary: PB_AMR_AJN
#    ✅ Created relationship: PB_AMR_AJN [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_BBK
#    ✅ Created relationship: PB_AMR_BBK [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_AM1
#    ✅ Created relationship: PB_AMR_AM1 [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_AMR_AM2
#    ✅ Created relationship: PB_AMR_AM2 [Tehsil] (parent: PB_AMR)
#    ✅ Created boundary: PB_LDH
#    ✅ Created relationship: PB_LDH [District] (parent: PB)
#    ✅ Created boundary: PB_LDH_LDH
#    ✅ Created relationship: PB_LDH_LDH [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_KHN
#    ✅ Created relationship: PB_LDH_KHN [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_SAM
#    ✅ Created relationship: PB_LDH_SAM [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_LDH_JAG
#    ✅ Created relationship: PB_LDH_JAG [Tehsil] (parent: PB_LDH)
#    ✅ Created boundary: PB_JAL
#    ✅ Created relationship: PB_JAL [District] (parent: PB)
#    ✅ Created boundary: PB_JAL_JAL
#    ✅ Created relationship: PB_JAL_JAL [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_JAL_NAK
#    ✅ Created relationship: PB_JAL_NAK [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_JAL_PHG
#    ✅ Created relationship: PB_JAL_PHG [Tehsil] (parent: PB_JAL)
#    ✅ Created boundary: PB_PTL
#    ✅ Created relationship: PB_PTL [District] (parent: PB)
#    ✅ Created boundary: PB_PTL_PTL
#    ✅ Created relationship: PB_PTL_PTL [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_PTL_RAJ
#    ✅ Created relationship: PB_PTL_RAJ [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_PTL_NAB
#    ✅ Created relationship: PB_PTL_NAB [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_PTL_SAM
#    ✅ Created relationship: PB_PTL_SAM [Tehsil] (parent: PB_PTL)
#    ✅ Created boundary: PB_BTH
#    ✅ Created relationship: PB_BTH [District] (parent: PB)
#    ✅ Created boundary: PB_BTH_BTH
#    ✅ Created relationship: PB_BTH_BTH [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_BTH_TAL
#    ✅ Created relationship: PB_BTH_TAL [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_BTH_RAM
#    ✅ Created relationship: PB_BTH_RAM [Tehsil] (parent: PB_BTH)
#    ✅ Created boundary: PB_FZK
#    ✅ Created relationship: PB_FZK [District] (parent: PB)
#    ✅ Created boundary: PB_FZK_FZK
#    ✅ Created relationship: PB_FZK_FZK [Tehsil] (parent: PB_FZK)
#    ✅ Created boundary: PB_FZK_ABO
#    ✅ Created relationship: PB_FZK_ABO [Tehsil] (parent: PB_FZK)
#    ✅ Created boundary: PB_SNG
#    ✅ Created relationship: PB_SNG [District] (parent: PB)
#    ✅ Created boundary: PB_SNG_SNG
#    ✅ Created relationship: PB_SNG_SNG [Tehsil] (parent: PB_SNG)
#    ✅ Created boundary: PB_SNG_AHM
#    ✅ Created relationship: PB_SNG_AHM [Tehsil] (parent: PB_SNG)
#    ✅ Created boundary: PB_SNG_BHW
#    ✅ Created relationship: PB_SNG_BHW [Tehsil] (parent: PB_SNG)
#    ✅ Created boundary: PB_SNG_MLK
#    ✅ Created relationship: PB_SNG_MLK [Tehsil] (parent: PB_SNG)
#    ✅ Created boundary: PB_HSP
#    ✅ Created relationship: PB_HSP [District] (parent: PB)
#    ✅ Created boundary: PB_HSP_HSP
#    ✅ Created relationship: PB_HSP_HSP [Tehsil] (parent: PB_HSP)
#    ✅ Created boundary: PB_HSP_DAS
#    ✅ Created relationship: PB_HSP_DAS [Tehsil] (parent: PB_HSP)
#    ✅ Created boundary: PB_HSP_GAR
#    ✅ Created relationship: PB_HSP_GAR [Tehsil] (parent: PB_HSP)
#    ✅ Created boundary: PB_GDS
#    ✅ Created relationship: PB_GDS [District] (parent: PB)
#    ✅ Created boundary: PB_GDS_GDS
#    ✅ Created relationship: PB_GDS_GDS [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_GDS_BTL
#    ✅ Created relationship: PB_GDS_BTL [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_GDS_DBN
#    ✅ Created relationship: PB_GDS_DBN [Tehsil] (parent: PB_GDS)
#    ✅ Created boundary: PB_KPT
#    ✅ Created relationship: PB_KPT [District] (parent: PB)
#    ✅ Created boundary: PB_KPT_KPT
#    ✅ Created relationship: PB_KPT_KPT [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_KPT_BHL
#    ✅ Created relationship: PB_KPT_BHL [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_KPT_PHG
#    ✅ Created relationship: PB_KPT_PHG [Tehsil] (parent: PB_KPT)
#    ✅ Created boundary: PB_MOG
#    ✅ Created relationship: PB_MOG [District] (parent: PB)
#    ✅ Created boundary: PB_MOG_MOG
#    ✅ Created relationship: PB_MOG_MOG [Tehsil] (parent: PB_MOG)
#    ✅ Created boundary: PB_MOG_BAG
#    ✅ Created relationship: PB_MOG_BAG [Tehsil] (parent: PB_MOG)
#    ✅ Created boundary: PB_FGS
#    ✅ Created relationship: PB_FGS [District] (parent: PB)
#    ✅ Created boundary: PB_FGS_FGS
#    ✅ Created relationship: PB_FGS_FGS [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_FGS_AML
#    ✅ Created relationship: PB_FGS_AML [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_FGS_BSP
#    ✅ Created relationship: PB_FGS_BSP [Tehsil] (parent: PB_FGS)
#    ✅ Created boundary: PB_RPN
#    ✅ Created relationship: PB_RPN [District] (parent: PB)
#    ✅ Created boundary: PB_RPN_RPN
#    ✅ Created relationship: PB_RPN_RPN [Tehsil] (parent: PB_RPN)
#    ✅ Created boundary: PB_RPN_ANS
#    ✅ Created relationship: PB_RPN_ANS [Tehsil] (parent: PB_RPN)
#    ✅ Created boundary: PB_SAS
#    ✅ Created relationship: PB_SAS [District] (parent: PB)
#    ✅ Created boundary: PB_SAS_MOH
#    ✅ Created relationship: PB_SAS_MOH [Tehsil] (parent: PB_SAS)
#    ✅ Created boundary: PB_SAS_DBS
#    ✅ Created relationship: PB_SAS_DBS [Tehsil] (parent: PB_SAS)
#    ✅ Created boundary: PB_SAS_KHR
#    ✅ Created relationship: PB_SAS_KHR [Tehsil] (parent: PB_SAS)
#    ✅ Created boundary: PB_SBS
#    ✅ Created relationship: PB_SBS [District] (parent: PB)
#    ✅ Created boundary: PB_SBS_NWS
#    ✅ Created relationship: PB_SBS_NWS [Tehsil] (parent: PB_SBS)
#    ✅ Created boundary: PB_SBS_BLC
#    ✅ Created relationship: PB_SBS_BLC [Tehsil] (parent: PB_SBS)
#    ✅ Created boundary: PB_SBS_BNG
#    ✅ Created relationship: PB_SBS_BNG [Tehsil] (parent: PB_SBS)
#    ✅ Created boundary: PB_TRN
#    ✅ Created relationship: PB_TRN [District] (parent: PB)
#    ✅ Created boundary: PB_TRN_TRN
#    ✅ Created relationship: PB_TRN_TRN [Tehsil] (parent: PB_TRN)
#    ✅ Created boundary: PB_TRN_BHK
#    ✅ Created relationship: PB_TRN_BHK [Tehsil] (parent: PB_TRN)
#    ✅ Created boundary: PB_TRN_PTT
#    ✅ Created relationship: PB_TRN_PTT [Tehsil] (parent: PB_TRN)
#    ✅ Created boundary: PB_BRN
#    ✅ Created relationship: PB_BRN [District] (parent: PB)
#    ✅ Created boundary: PB_BRN_BRN
#    ✅ Created relationship: PB_BRN_BRN [Tehsil] (parent: PB_BRN)
#    ✅ Created boundary: PB_BRN_TPA
#    ✅ Created relationship: PB_BRN_TPA [Tehsil] (parent: PB_BRN)
#    ✅ Created boundary: PB_MNS
#    ✅ Created relationship: PB_MNS [District] (parent: PB)
#    ✅ Created boundary: PB_MNS_MNS
#    ✅ Created relationship: PB_MNS_MNS [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_MNS_BDR
#    ✅ Created relationship: PB_MNS_BDR [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_MNS_SRD
#    ✅ Created relationship: PB_MNS_SRD [Tehsil] (parent: PB_MNS)
#    ✅ Created boundary: PB_FRP
#    ✅ Created relationship: PB_FRP [District] (parent: PB)
#    ✅ Created boundary: PB_FRP_FRP
#    ✅ Created relationship: PB_FRP_FRP [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_FRP_ZRA
#    ✅ Created relationship: PB_FRP_ZRA [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_FRP_GUR
#    ✅ Created relationship: PB_FRP_GUR [Tehsil] (parent: PB_FRP)
#    ✅ Created boundary: PB_MKT
#    ✅ Created relationship: PB_MKT [District] (parent: PB)
#    ✅ Created boundary: PB_MKT_MKT
#    ✅ Created relationship: PB_MKT_MKT [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_MKT_MLT
#    ✅ Created relationship: PB_MKT_MLT [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_MKT_GDW
#    ✅ Created relationship: PB_MKT_GDW [Tehsil] (parent: PB_MKT)
#    ✅ Created boundary: PB_FRD
#    ✅ Created relationship: PB_FRD [District] (parent: PB)
#    ✅ Created boundary: PB_FRD_FRD
#    ✅ Created relationship: PB_FRD_FRD [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_FRD_KTK
#    ✅ Created relationship: PB_FRD_KTK [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_FRD_JTN
#    ✅ Created relationship: PB_FRD_JTN [Tehsil] (parent: PB_FRD)
#    ✅ Created boundary: PB_PTK
#    ✅ Created relationship: PB_PTK [District] (parent: PB)
#    ✅ Created boundary: PB_PTK_PTK
#    ✅ Created relationship: PB_PTK_PTK [Tehsil] (parent: PB_PTK)
#    ✅ Created boundary: PB_PTK_DNN
#    ✅ Created relationship: PB_PTK_DNN [Tehsil] (parent: PB_PTK)
#
# ✅ Boundary processing completed!
#    Boundaries created: 88
#    Relationships created: 88
#
#    Status: completed
# {'status': 'completed',
#  'boundaries_created': 88,
#  'relationships_created': 88,
#  'errors': []}

# %%
# Phase 3 - Common Masters
loader.load_common_masters("templates/Common and Complaint Master.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master.xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: statea
#    ✅ Found 23 department(s)
# 📥 Fetching designations from MDMS for tenant: statea
#    ✅ Found 44 designation(s)
#    Creating 2 designations...
#
# [UPLOADING] common-masters.Designation
#    Tenant: statea
#    Records: 2
#    API URL: https://chakshu-digit.egov.theflywheel.in/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [OK] [1/2] DESIG_1010
#    [OK] [2/2] DESIG_1011
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Designation
#    ⚠️  Sheet 'Designation' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: statea
#    Total Messages: 2
#    API URL: https://chakshu-digit.egov.theflywheel.in/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: statea
#    Records: 1
#    API URL: https://chakshu-digit.egov.theflywheel.in/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [EXISTS] [1/1] TabBroken (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: statea
#    Total Messages: 2
#    API URL: https://chakshu-digit.egov.theflywheel.in/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 500...
#       ✅ Batch 1/1: 2 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created: 2
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'departments': None,
#  'designations': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'complaint_types': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []}}

# %%
# Phase 4 - Employees
loader.load_employees("templates/Employee_Master_Dynamic_statea.xlsx", target_tenant=TARGET_TENANT)
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea.xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: statea
#    ✅ Found 23 department(s)
# 📥 Fetching designations from MDMS for tenant: statea
#    ✅ Found 46 designation(s)
# 📥 Fetching roles from MDMS for tenant: statea
#    ✅ Found 20 role(s) from MDMS
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: statea
#    ✅ Found 20 existing roles in MDMS
#    ✅ All 20 required roles already exist in MDMS
#
# ============================================================
# [UPLOADING] HRMS Employees
#    Tenant: statea
#    Records: 1
#    API URL: https://chakshu-digit.egov.theflywheel.in/egov-hrms/employees/_create
# ============================================================
#    [EXISTS] [1/1] SAMPLE_EMPLOYEE (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Password Updated: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Employee_Master_Dynamic_statea.xlsx
#    Sheet: Employee Master
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# ────────────────────────────────────────
# Employees Summary:
#    Created: 0
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'created': 0, 'exists': 1, 'failed': 0, 'errors': [], 'password_updated': 0}

# %% [markdown]
# ---
#
# ## Phase 5: Localizations (Optional)
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations (Optional)
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
# loader.load_localizations("templates/localization.xlsx", target_tenant=TARGET_TENANT)

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     "templates/localization.xlsx",
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )

# %% [markdown]
# ---
#
# ## Rollback / Delete Data
#
# Use these cells to undo data loading. Run only what you need to rollback.

# %%
# Rollback Phase 2 - Delete Boundaries
# Deletes all boundary entities and relationships for the tenant
loader.delete_boundaries(TARGET_TENANT)
# Out:
# ============================================================
# DELETING BOUNDARIES
# ============================================================
# Tenant: statea
#    Boundaries deleted: 0
#    Relationships deleted: 0
# ============================================================
# {'deleted': 0, 'relationships_deleted': 0, 'status': 'success'}

# %%
# Rollback Phase 3 - Delete Common Masters
# Deletes departments, designations, and complaint types
loader.rollback_common_masters(TARGET_TENANT)
# Out:
# ============================================================
# MDMS ROLLBACK
# ============================================================
# Tenant: statea
# Schemas: common-masters.Department, common-masters.Designation, RAINMAKER-PGR.ServiceDefs
#
# 🗑️ Deleting MDMS data: common-masters.Department for tenant: statea
#    Found 23 records
#    ❌ Failed to delete DEPT_37: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_36: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT002: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT001: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883745186_DEPT_2: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883745186_DEPT_1: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883389285_DEPT_2: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883389285_DEPT_1: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TESTDEPT1768883297913: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TESTDEPT1768883252618: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_1: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_2: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_3: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_4: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_5: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_6: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_7: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_8: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_9: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_10: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_13: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_25: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DEPT_35: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#
#    Summary: Deleted 0, Failed 23, Skipped 0
#
# 🗑️ Deleting MDMS data: common-masters.Designation for tenant: statea
#    Found 46 records
#    ❌ Failed to delete DESIG_1011: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1010: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1009: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1008: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1007: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1006: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1005: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1004: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1003: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1002: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG002: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG001: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883745186_DESIG_2: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883745186_DESIG_1: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883389285_DESIG_2: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TEST1768883389285_DESIG_1: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete TESTDESIG1768883298377: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_01: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_02: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_03: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_04: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_05: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_06: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_07: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_08: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_09: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_10: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_11: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_12: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_13: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_14: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_15: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_16: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_17: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_18: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_19: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_20: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_21: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_22: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_23: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_1001: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_58: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_24: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DESIG_47: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete AO: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete COMM: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#
#    Summary: Deleted 0, Failed 46, Skipped 0
#
# 🗑️ Deleting MDMS data: RAINMAKER-PGR.ServiceDefs for tenant: statea
#    Found 8 records
#    ❌ Failed to delete TabBroken: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete SVC001: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete StreetLightNotWorking: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete NonSweepingOfRoad: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete NoStreetlight: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete GarbageNeedsTobeCleared: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete DamagedGarbageBin: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#    ❌ Failed to delete BurningOfGarbage: {"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet
#
#    Summary: Deleted 0, Failed 8, Skipped 0
#
# ────────────────────────────────────────
# Rollback Complete: 0 deleted, 77 failed
# ────────────────────────────────────────
# {'common-masters.Department': {'deleted': 0,
#   'failed': 23,
#   'skipped': 0,
#   'errors': [{'id': 'DEPT_37',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_36',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT002',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT001',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883745186_DEPT_2',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883745186_DEPT_1',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883389285_DEPT_2',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883389285_DEPT_1',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TESTDEPT1768883297913',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TESTDEPT1768883252618',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_1',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_2',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_3',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_4',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_5',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_6',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_7',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_8',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_9',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_10',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_13',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_25',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DEPT_35',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'}]},
#  'common-masters.Designation': {'deleted': 0,
#   'failed': 46,
#   'skipped': 0,
#   'errors': [{'id': 'DESIG_1011',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1010',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1009',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1008',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1007',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1006',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1005',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1004',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1003',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1002',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG002',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG001',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883745186_DESIG_2',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883745186_DESIG_1',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883389285_DESIG_2',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TEST1768883389285_DESIG_1',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'TESTDESIG1768883298377',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_01',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_02',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_03',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_04',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_05',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_06',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_07',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_08',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_09',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_10',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_11',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_12',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_13',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_14',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_15',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_16',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_17',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_18',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_19',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_20',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_21',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_22',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_23',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_1001',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_58',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_24',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DESIG_47',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'AO',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'COMM',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'}]},
#  'RAINMAKER-PGR.ServiceDefs': {'deleted': 0,
#   'failed': 8,
#   'skipped': 0,
#   'errors': [{'id': 'TabBroken',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'SVC001',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'StreetLightNotWorking',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'NonSweepingOfRoad',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'NoStreetlight',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'GarbageNeedsTobeCleared',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'DamagedGarbageBin',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'},
#    {'id': 'BurningOfGarbage',
#     'error': '{"ResponseInfo":{"apiId":"asset-services","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"delet'}]}}

# %%
# Rollback Phase 1 - Delete Tenant Config
# Deletes tenant and branding configuration
loader.rollback_tenant(TARGET_TENANT)

# %%
# Delete specific MDMS schema data (granular control)
loader.delete_mdms("common-masters.Department", TARGET_TENANT)
loader.delete_mdms("common-masters.Designation", TARGET_TENANT)
loader.delete_mdms("RAINMAKER-PGR.ServiceDefs", TARGET_TENANT)

# %%
# FULL RESET - Delete everything (MDMS + Boundaries)
# WARNING: This deletes ALL data for the tenant!
loader.full_reset("REVENUE", TARGET_TENANT)

# %% [markdown]
# **Note:** Employees (Phase 4) cannot be deleted via API - they are managed in HRMS and must be deactivated manually if needed.
